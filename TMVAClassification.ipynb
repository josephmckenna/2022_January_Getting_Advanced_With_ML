# %%
from ROOT import TMVA, TFile, TTree, TCut
from subprocess import call
from os.path import isfile
 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import SGD
# Out:
# Welcome to JupyROOT 6.24/06
# 2022-02-08 14:24:21.492720: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /cvmfs/sft.cern.ch/lcg/releases/MCGenerators/thepeg/2.2.1-8d929/x86_64-centos7-gcc8-opt/lib/ThePEG:/cvmfs/sft.cern.ch/lcg/releases/MCGenerators/herwig++/7.2.1-f3599/x86_64-centos7-gcc8-opt/lib/Herwig:/cvmfs/sft.cern.ch/lcg/views/LCG_101swan/x86_64-centos7-gcc8-opt/lib/python3.9/site-packages/torch/lib:/cvmfs/sft.cern.ch/lcg/views/LCG_101swan/x86_64-centos7-gcc8-opt/lib/python3.9/site-packages/tensorflow:/cvmfs/sft.cern.ch/lcg/views/LCG_101swan/x86_64-centos7-gcc8-opt/lib/python3.9/site-packages/tensorflow/contrib/tensor_forest:/cvmfs/sft.cern.ch/lcg/views/LCG_101swan/x86_64-centos7-gcc8-opt/lib/python3.9/site-packages/tensorflow/python/framework:/cvmfs/sft.cern.ch/lcg/releases/java/8u222-884d8/x86_64-centos7-gcc8-opt/jre/lib/amd64:/cvmfs/sft.cern.ch/lcg/views/LCG_101swan/x86_64-centos7-gcc8-opt/lib64:/cvmfs/sft.cern.ch/lcg/views/LCG_101swan/x86_64-centos7-gcc8-opt/lib:/cvmfs/sft.cern.ch/lcg/releases/gcc/8.3.0-cebb0/x86_64-centos7/lib:/cvmfs/sft.cern.ch/lcg/releases/gcc/8.3.0-cebb0/x86_64-centos7/lib64:/cvmfs/sft.cern.ch/lcg/releases/binutils/2.30-e5b21/x86_64-centos7/lib:/usr/local/lib/:/cvmfs/sft.cern.ch/lcg/releases/R/3.6.3-dfb24/x86_64-centos7-gcc8-opt/lib64/R/library/readr/rcon
# 2022-02-08 14:24:21.492773: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# Setup TMVA
TMVA.Tools.Instance()
TMVA.PyMethodBase.PyInitialize()

# Fastest (and smallest) dataset
data = TFile.Open('10k_sample_data.root')
# Medium size dataset
# data = TFile.Open('50k_sample_data.root')
signal = data.Get('Mixing')
background = data.Get('Cosmic')

# %%
dataloader = TMVA.DataLoader('dataset')

variable_list = [
   'nhits',
   'residual',
   'r',
   'S0rawPerp',
   'S0axisrawZ',
   'phi_S0axisraw',
   'nCT',
   'nGT',
   'tracksdca',
   'curvemin',
   'curvemean',
   'lambdamin',
   'lambdamean',
   'curvesign',
   # Want to see the final tests fail? Enable these
   #'phi',
   #'X',
   #'Y',
   #'Z',
]
# Assign the variables for training (and testing)
for variable in variable_list:
    dataloader.AddVariable(variable)

# %%
dataloader.AddSignalTree(signal, 1.0)
dataloader.AddBackgroundTree(background, 1.0)

testing_events = 4000

dataloader.PrepareTrainingAndTestTree(TCut(''),
                                      'nTrain_Signal=' +
                                      str(signal.GetEntries() - testing_events) + 
                                      ':nTrain_Background=' +
                                      str(background.GetEntries() - testing_events) + 
                                      ':SplitMode=Random:NormMode=NumEvents:!V')
# Out:
# DataSetInfo              : [dataset] : Added class "Signal"
#                          : Add Tree Mixing of type Signal with 10000 events
# DataSetInfo              : [dataset] : Added class "Background"
#                          : Add Tree Cosmic of type Background with 10000 events
#                          : Dataset[dataset] : Class index : 0  name : Signal
#                          : Dataset[dataset] : Class index : 1  name : Background

# %% [markdown]
# # Select the classifiers of interest here:

# %%
# Maybe pick one or two out of this list if memory is limited
active_mva_list = [
    'Fisher',
    'PyKeras',
    'Cuts',
    'KNN',
    'SVM',
    'BDT',
    'BDTB',
    'BDTG',
]

# %%
output = TFile.Open('TMVA.root', 'RECREATE')
factory = TMVA.Factory('TMVAClassification', output,
                       '!V:!Silent:Color:DrawProgressBar:Transformations=D,G:AnalysisType=Classification')


# Book methods

if 'Fisher' in active_mva_list:
    factory.BookMethod(dataloader, TMVA.Types.kFisher, 'Fisher',
                       '!H:!V:Fisher:VarTransform=D,G')
if 'PyKeras' in active_mva_list:
    # Generate model
    
    # Define model
    model = Sequential()
    model.add(Dense(64, activation='relu', input_dim=len(variable_list)))
    model.add(Dense(2, activation='softmax'))
    
    # Set loss and optimizer
    model.compile(loss='categorical_crossentropy',
                  optimizer=SGD(lr=0.01), metrics=['accuracy', ])
    # Store model to file
    model.save('model.h5')
    model.summary()
    factory.BookMethod(dataloader, TMVA.Types.kPyKeras, 'PyKeras',
                       'H:!V:VarTransform=D,G:FilenameModel=model.h5:NumEpochs=20:BatchSize=32')
# Cut optimisation
if 'Cuts' in active_mva_list:
    factory.BookMethod( dataloader, TMVA.Types.kCuts, 'Cuts',
                        '!H:!V:FitMethod=MC:EffSel:SampleSize=200000:VarProp=FSmart' )
#// K-Nearest Neighbour classifier (KNN)
if 'KNN' in active_mva_list:
    factory.BookMethod( dataloader, TMVA.Types.kKNN, 'KNN',
                       '!H:nkNN=20:ScaleFrac=0.8:SigmaFact=1.0:Kernel=Gaus:UseKernel=F:UseWeight=T:!Trim' )

# Support Vector Machine
if 'SVM' in active_mva_list:
    factory.BookMethod( dataloader, TMVA.Types.kSVM, 'SVM', 'Gamma=0.25:Tol=0.001:VarTransform=Norm' )

# "BDT"  // Adaptive Boost
if 'BDT' in active_mva_list:
    factory.BookMethod( dataloader, TMVA.Types.kBDT, 'BDT',
                       '!H:!V:NTrees=850:MinNodeSize=2.5%:MaxDepth=3:BoostType=AdaBoost:AdaBoostBeta=0.5:UseBaggedBoost:BaggedSampleFraction=0.5:SeparationType=GiniIndex:nCuts=20:SigToBkgFraction=1.0' )

# "BDTB" // Bagging random forest
if 'BDTB' in active_mva_list:
    factory.BookMethod( dataloader, TMVA.Types.kBDT, 'BDTB',
                      '!H:!V:NTrees=500:BoostType=AdaBoost:AdaBoostBeta=0.5:UseBaggedBoost:BaggedSampleFraction=1.0:SeparationType=GiniIndex:nCuts=50:MaxDepth=4:MinNodeSize=5.0%:UseRandomisedTrees:UseNvars=4:CreateMVAPdfs' )

# "BDTG" // Gradient Boost
if 'BDTG' in active_mva_list:  
    factory.BookMethod( dataloader, TMVA.Types.kBDT, 'BDTG',
                        '!H:!V:NTrees=1000:MinNodeSize=2.5%:BoostType=Grad:Shrinkage=0.10:UseBaggedBoost:BaggedSampleFraction=0.5:nCuts=20:MaxDepth=2:SigToBkgFraction=1.0' )
# Out:
# /cvmfs/sft.cern.ch/lcg/views/LCG_101swan/x86_64-centos7-gcc8-opt/lib/python3.9/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                960
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 1,090
# Trainable params: 1,090
# Non-trainable params: 0
# _________________________________________________________________
# Factory                  : Booking method: Fisher
#                          :
# Fisher                   : [dataset] : Create Transformation "D" with events from all classes.
#                          :
#                          : Transformation, Variable selection :
#                          : Input : variable 'nhits' <---> Output : variable 'nhits'
#                          : Input : variable 'residual' <---> Output : variable 'residual'
#                          : Input : variable 'r' <---> Output : variable 'r'
#                          : Input : variable 'S0rawPerp' <---> Output : variable 'S0rawPerp'
#                          : Input : variable 'S0axisrawZ' <---> Output : variable 'S0axisrawZ'
#                          : Input : variable 'phi_S0axisraw' <---> Output : variable 'phi_S0axisraw'
#                          : Input : variable 'nCT' <---> Output : variable 'nCT'
#                          : Input : variable 'nGT' <---> Output : variable 'nGT'
#                          : Input : variable 'tracksdca' <---> Output : variable 'tracksdca'
#                          : Input : variable 'curvemin' <---> Output : variable 'curvemin'
#                          : Input : variable 'curvemean' <---> Output : variable 'curvemean'
#                          : Input : variable 'lambdamin' <---> Output : variable 'lambdamin'
#                          : Input : variable 'lambdamean' <---> Output : variable 'lambdamean'
#                          : Input : variable 'curvesign' <---> Output : variable 'curvesign'
# Fisher                   : [dataset] : Create Transformation "G" with events from all classes.
#                          :
#                          : Transformation, Variable selection :
#                          : Input : variable 'nhits' <---> Output : variable 'nhits'
#                          : Input : variable 'residual' <---> Output : variable 'residual'
#                          : Input : variable 'r' <---> Output : variable 'r'
#                          : Input : variable 'S0rawPerp' <---> Output : variable 'S0rawPerp'
#                          : Input : variable 'S0axisrawZ' <---> Output : variable 'S0axisrawZ'
#                          : Input : variable 'phi_S0axisraw' <---> Output : variable 'phi_S0axisraw'
#                          : Input : variable 'nCT' <---> Output : variable 'nCT'
#                          : Input : variable 'nGT' <---> Output : variable 'nGT'
#                          : Input : variable 'tracksdca' <---> Output : variable 'tracksdca'
#                          : Input : variable 'curvemin' <---> Output : variable 'curvemin'
#                          : Input : variable 'curvemean' <---> Output : variable 'curvemean'
#                          : Input : variable 'lambdamin' <---> Output : variable 'lambdamin'
#                          : Input : variable 'lambdamean' <---> Output : variable 'lambdamean'
#                          : Input : variable 'curvesign' <---> Output : variable 'curvesign'
# Factory                  : Booking method: PyKeras
#                          :
# PyKeras                  : [dataset] : Create Transformation "D" with events from all classes.
#                          :
#                          : Transformation, Variable selection :
#                          : Input : variable 'nhits' <---> Output : variable 'nhits'
#                          : Input : variable 'residual' <---> Output : variable 'residual'
#                          : Input : variable 'r' <---> Output : variable 'r'
#                          : Input : variable 'S0rawPerp' <---> Output : variable 'S0rawPerp'
#                          : Input : variable 'S0axisrawZ' <---> Output : variable 'S0axisrawZ'
#                          : Input : variable 'phi_S0axisraw' <---> Output : variable 'phi_S0axisraw'
#                          : Input : variable 'nCT' <---> Output : variable 'nCT'
#                          : Input : variable 'nGT' <---> Output : variable 'nGT'
#                          : Input : variable 'tracksdca' <---> Output : variable 'tracksdca'
#                          : Input : variable 'curvemin' <---> Output : variable 'curvemin'
#                          : Input : variable 'curvemean' <---> Output : variable 'curvemean'
#                          : Input : variable 'lambdamin' <---> Output : variable 'lambdamin'
#                          : Input : variable 'lambdamean' <---> Output : variable 'lambdamean'
#                          : Input : variable 'curvesign' <---> Output : variable 'curvesign'
# PyKeras                  : [dataset] : Create Transformation "G" with events from all classes.
#                          :
#                          : Transformation, Variable selection :
#                          : Input : variable 'nhits' <---> Output : variable 'nhits'
#                          : Input : variable 'residual' <---> Output : variable 'residual'
#                          : Input : variable 'r' <---> Output : variable 'r'
#                          : Input : variable 'S0rawPerp' <---> Output : variable 'S0rawPerp'
#                          : Input : variable 'S0axisrawZ' <---> Output : variable 'S0axisrawZ'
#                          : Input : variable 'phi_S0axisraw' <---> Output : variable 'phi_S0axisraw'
#                          : Input : variable 'nCT' <---> Output : variable 'nCT'
#                          : Input : variable 'nGT' <---> Output : variable 'nGT'
#                          : Input : variable 'tracksdca' <---> Output : variable 'tracksdca'
#                          : Input : variable 'curvemin' <---> Output : variable 'curvemin'
#                          : Input : variable 'curvemean' <---> Output : variable 'curvemean'
#                          : Input : variable 'lambdamin' <---> Output : variable 'lambdamin'
#                          : Input : variable 'lambdamean' <---> Output : variable 'lambdamean'
#                          : Input : variable 'curvesign' <---> Output : variable 'curvesign'
#                          : Setting up keras with
#                          :
#                          :
# <WARNING>                :
#                          :
#                          :
#                          :
# Factory                  : Booking method: Cuts
#                          :
#                          : Use optimization method: "Monte Carlo"
#                          : Use efficiency computation method: "Event Selection"
#                          : Use "FSmart" cuts for variable: 'nhits'
#                          : Use "FSmart" cuts for variable: 'residual'
#                          : Use "FSmart" cuts for variable: 'r'
#                          : Use "FSmart" cuts for variable: 'S0rawPerp'
#                          : Use "FSmart" cuts for variable: 'S0axisrawZ'
#                          : Use "FSmart" cuts for variable: 'phi_S0axisraw'
#                          : Use "FSmart" cuts for variable: 'nCT'
#                          : Use "FSmart" cuts for variable: 'nGT'
#                          : Use "FSmart" cuts for variable: 'tracksdca'
#                          : Use "FSmart" cuts for variable: 'curvemin'
#                          : Use "FSmart" cuts for variable: 'curvemean'
#                          : Use "FSmart" cuts for variable: 'lambdamin'
#                          : Use "FSmart" cuts for variable: 'lambdamean'
#                          : Use "FSmart" cuts for variable: 'curvesign'
# Factory                  : Booking method: KNN
#                          :
# Factory                  : Booking method: SVM
#                          :
# SVM                      : [dataset] : Create Transformation "Norm" with events from all classes.
#                          :
#                          : Transformation, Variable selection :
#                          : Input : variable 'nhits' <---> Output : variable 'nhits'
#                          : Input : variable 'residual' <---> Output : variable 'residual'
#                          : Input : variable 'r' <---> Output : variable 'r'
#                          : Input : variable 'S0rawPerp' <---> Output : variable 'S0rawPerp'
#                          : Input : variable 'S0axisrawZ' <---> Output : variable 'S0axisrawZ'
#                          : Input : variable 'phi_S0axisraw' <---> Output : variable 'phi_S0axisraw'
#                          : Input : variable 'nCT' <---> Output : variable 'nCT'
#                          : Input : variable 'nGT' <---> Output : variable 'nGT'
#                          : Input : variable 'tracksdca' <---> Output : variable 'tracksdca'
#                          : Input : variable 'curvemin' <---> Output : variable 'curvemin'
#                          : Input : variable 'curvemean' <---> Output : variable 'curvemean'
#                          : Input : variable 'lambdamin' <---> Output : variable 'lambdamin'
#                          : Input : variable 'lambdamean' <---> Output : variable 'lambdamean'
#                          : Input : variable 'curvesign' <---> Output : variable 'curvesign'
# Factory                  : Booking method: BDT
#                          :
#                          : Building event vectors for type 2 Signal
#                          : Dataset[dataset] :  create input formulas for tree Mixing
#                          : Building event vectors for type 2 Background
#                          : Dataset[dataset] :  create input formulas for tree Cosmic
# DataSetFactory           : [dataset] : Number of events in input trees
#                          :
#                          :
#                          : Number of training and testing events
#                          : ---------------------------------------------------------------------------
#                          : Signal     -- training events            : 6000
#                          : Signal     -- testing events             : 4000
#                          : Signal     -- training and testing events: 10000
#                          : Background -- training events            : 6000
#                          : Background -- testing events             : 4000
#                          : Background -- training and testing events: 10000
#                          :
# DataSetInfo              : Correlation matrix (Signal):
#                          : ------------------------------------------------------------------------------------------------------------------------------------------------------
#                          :                  nhits residual       r S0rawPerp S0axisrawZ phi_S0axisraw     nCT     nGT tracksdca curvemin curvemean lambdamin lambdamean curvesign
#                          :         nhits:  +1.000   -0.064  +0.177    -0.310     -0.192        +0.023  +0.576  +0.578    +0.411   +0.191    +0.258    +0.191     -0.012    -0.038
#                          :      residual:  -0.064   +1.000  +0.241    -0.169     +0.098        +0.049  -0.139  -0.080    +0.154   -0.096    +0.142    -0.096     +0.203    -0.003
#                          :             r:  +0.177   +0.241  +1.000    -0.125     +0.116        +0.081  +0.187  +0.279    +0.414   -0.116    +0.291    -0.116     +0.005    -0.019
#                          :     S0rawPerp:  -0.310   -0.169  -0.125    +1.000     -0.027        -0.135  -0.600  -0.455    -0.286   +0.026    -0.148    +0.026     -0.072    +0.006
#                          :    S0axisrawZ:  -0.192   +0.098  +0.116    -0.027     +1.000        +0.017  +0.184  +0.151    +0.069   -0.999    +0.110    -0.999     +0.170    -0.003
#                          : phi_S0axisraw:  +0.023   +0.049  +0.081    -0.135     +0.017        +1.000  +0.089  +0.060    +0.035   -0.018    +0.025    -0.018     -0.029    +0.014
#                          :           nCT:  +0.576   -0.139  +0.187    -0.600     +0.184        +0.089  +1.000  +0.887    +0.467   -0.184    +0.246    -0.184     -0.008    -0.035
#                          :           nGT:  +0.578   -0.080  +0.279    -0.455     +0.151        +0.060  +0.887  +1.000    +0.637   -0.152    +0.335    -0.152     +0.017    -0.038
#                          :     tracksdca:  +0.411   +0.154  +0.414    -0.286     +0.069        +0.035  +0.467  +0.637    +1.000   -0.070    +0.470    -0.070     +0.036    -0.017
#                          :      curvemin:  +0.191   -0.096  -0.116    +0.026     -0.999        -0.018  -0.184  -0.152    -0.070   +1.000    -0.110    +1.000     -0.170    +0.003
#                          :     curvemean:  +0.258   +0.142  +0.291    -0.148     +0.110        +0.025  +0.246  +0.335    +0.470   -0.110    +1.000    -0.110     +0.094    -0.019
#                          :     lambdamin:  +0.191   -0.096  -0.116    +0.026     -0.999        -0.018  -0.184  -0.152    -0.070   +1.000    -0.110    +1.000     -0.170    +0.003
#                          :    lambdamean:  -0.012   +0.203  +0.005    -0.072     +0.170        -0.029  -0.008  +0.017    +0.036   -0.170    +0.094    -0.170     +1.000    -0.024
#                          :     curvesign:  -0.038   -0.003  -0.019    +0.006     -0.003        +0.014  -0.035  -0.038    -0.017   +0.003    -0.019    +0.003     -0.024    +1.000
#                          : ------------------------------------------------------------------------------------------------------------------------------------------------------
# DataSetInfo              : Correlation matrix (Background):
#                          : ------------------------------------------------------------------------------------------------------------------------------------------------------
#                          :                  nhits residual       r S0rawPerp S0axisrawZ phi_S0axisraw     nCT     nGT tracksdca curvemin curvemean lambdamin lambdamean curvesign
#                          :         nhits:  +1.000   -0.011  -0.028    +0.006     -0.079        +0.014  -0.052  -0.053    -0.007   +0.079    -0.013    +0.079     -0.030    -0.002
#                          :      residual:  -0.011   +1.000  +0.401    -0.502     +0.159        +0.123  +0.326  +0.326    +0.529   -0.159    +0.334    -0.159     +0.059    +0.011
#                          :             r:  -0.028   +0.401  +1.000    -0.230     +0.364        +0.268  +0.680  +0.686    +0.253   -0.364    +0.035    -0.364     +0.044    +0.057
#                          :     S0rawPerp:  +0.006   -0.502  -0.230    +1.000     +0.004        -0.095  -0.324  -0.317    -0.492   -0.004    -0.326    -0.004     +0.013    -0.001
#                          :    S0axisrawZ:  -0.079   +0.159  +0.364    +0.004     +1.000        -0.017  +0.685  +0.688    +0.115   -1.000    +0.180    -1.000     +0.389    +0.031
#                          : phi_S0axisraw:  +0.014   +0.123  +0.268    -0.095     -0.017        +1.000  +0.205  +0.205    +0.090   +0.017    -0.000    +0.017     -0.068    -0.019
#                          :           nCT:  -0.052   +0.326  +0.680    -0.324     +0.685        +0.205  +1.000  +0.997    +0.388   -0.685    +0.137    -0.685     +0.192    +0.027
#                          :           nGT:  -0.053   +0.326  +0.686    -0.317     +0.688        +0.205  +0.997  +1.000    +0.388   -0.688    +0.136    -0.688     +0.194    +0.027
#                          :     tracksdca:  -0.007   +0.529  +0.253    -0.492     +0.115        +0.090  +0.388  +0.388    +1.000   -0.116    +0.315    -0.116     +0.035    +0.036
#                          :      curvemin:  +0.079   -0.159  -0.364    -0.004     -1.000        +0.017  -0.685  -0.688    -0.116   +1.000    -0.180    +1.000     -0.390    -0.030
#                          :     curvemean:  -0.013   +0.334  +0.035    -0.326     +0.180        -0.000  +0.137  +0.136    +0.315   -0.180    +1.000    -0.180     +0.115    +0.005
#                          :     lambdamin:  +0.079   -0.159  -0.364    -0.004     -1.000        +0.017  -0.685  -0.688    -0.116   +1.000    -0.180    +1.000     -0.389    -0.030
#                          :    lambdamean:  -0.030   +0.059  +0.044    +0.013     +0.389        -0.068  +0.192  +0.194    +0.035   -0.390    +0.115    -0.389     +1.000    +0.000
#                          :     curvesign:  -0.002   +0.011  +0.057    -0.001     +0.031        -0.019  +0.027  +0.027    +0.036   -0.030    +0.005    -0.030     +0.000    +1.000
#                          : ------------------------------------------------------------------------------------------------------------------------------------------------------
# DataSetFactory           : [dataset] :
#                          :
# Factory                  : Booking method: BDTB
#                          :
#                          :  Randomised trees use no pruning
# Factory                  : Booking method: BDTG
#                          :
#                          : the option NegWeightTreatment=InverseBoostNegWeights does not exist for BoostType=Grad
#                          : --> change to new default NegWeightTreatment=Pray
# 2022-02-08 14:24:29.210838: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /cvmfs/sft.cern.ch/lcg/releases/MCGenerators/thepeg/2.2.1-8d929/x86_64-centos7-gcc8-opt/lib/ThePEG:/cvmfs/sft.cern.ch/lcg/releases/MCGenerators/herwig++/7.2.1-f3599/x86_64-centos7-gcc8-opt/lib/Herwig:/cvmfs/sft.cern.ch/lcg/views/LCG_101swan/x86_64-centos7-gcc8-opt/lib/python3.9/site-packages/torch/lib:/cvmfs/sft.cern.ch/lcg/views/LCG_101swan/x86_64-centos7-gcc8-opt/lib/python3.9/site-packages/tensorflow:/cvmfs/sft.cern.ch/lcg/views/LCG_101swan/x86_64-centos7-gcc8-opt/lib/python3.9/site-packages/tensorflow/contrib/tensor_forest:/cvmfs/sft.cern.ch/lcg/views/LCG_101swan/x86_64-centos7-gcc8-opt/lib/python3.9/site-packages/tensorflow/python/framework:/cvmfs/sft.cern.ch/lcg/releases/java/8u222-884d8/x86_64-centos7-gcc8-opt/jre/lib/amd64:/cvmfs/sft.cern.ch/lcg/views/LCG_101swan/x86_64-centos7-gcc8-opt/lib64:/cvmfs/sft.cern.ch/lcg/views/LCG_101swan/x86_64-centos7-gcc8-opt/lib:/cvmfs/sft.cern.ch/lcg/releases/gcc/8.3.0-cebb0/x86_64-centos7/lib:/cvmfs/sft.cern.ch/lcg/releases/gcc/8.3.0-cebb0/x86_64-centos7/lib64:/cvmfs/sft.cern.ch/lcg/releases/binutils/2.30-e5b21/x86_64-centos7/lib:/usr/local/lib/:/cvmfs/sft.cern.ch/lcg/releases/R/3.6.3-dfb24/x86_64-centos7-gcc8-opt/lib64/R/library/readr/rcon
# 2022-02-08 14:24:29.211235: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-02-08 14:24:29.211759: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (489ac9f57133): /proc/driver/nvidia/version does not exist
# 2022-02-08 14:24:29.217285: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Train our classifiers! This can take some time

# %%
# Run training, test and evaluation
factory.TrainAllMethods()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                960
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 1,090
# Trainable params: 1,090
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 300/300 [==============================] - 2s 4ms/step - loss: 0.4428 - accuracy: 0.8281 - val_loss: 0.3105 - val_accuracy: 0.9038
#
# Epoch 00001: val_loss improved from inf to 0.31050, saving model to dataset/weights/TrainedModel_PyKeras.h5
# Epoch 2/20
# 300/300 [==============================] - 0s 1ms/step - loss: 0.2726 - accuracy: 0.9051 - val_loss: 0.2541 - val_accuracy: 0.9071
#
# Epoch 00002: val_loss improved from 0.31050 to 0.25406, saving model to dataset/weights/TrainedModel_PyKeras.h5
# Epoch 3/20
# 300/300 [==============================] - 0s 1ms/step - loss: 0.2391 - accuracy: 0.9095 - val_loss: 0.2354 - val_accuracy: 0.9112
#
# Epoch 00003: val_loss improved from 0.25406 to 0.23543, saving model to dataset/weights/TrainedModel_PyKeras.h5
# Epoch 4/20
# 300/300 [==============================] - 0s 1ms/step - loss: 0.2252 - accuracy: 0.9106 - val_loss: 0.2253 - val_accuracy: 0.9125
#
# Epoch 00004: val_loss improved from 0.23543 to 0.22527, saving model to dataset/weights/TrainedModel_PyKeras.h5
# Epoch 5/20
# 300/300 [==============================] - 0s 1ms/step - loss: 0.2172 - accuracy: 0.9131 - val_loss: 0.2194 - val_accuracy: 0.9150
#
# Epoch 00005: val_loss improved from 0.22527 to 0.21938, saving model to dataset/weights/TrainedModel_PyKeras.h5
# Epoch 6/20
# 300/300 [==============================] - 0s 1ms/step - loss: 0.2119 - accuracy: 0.9145 - val_loss: 0.2138 - val_accuracy: 0.9146
#
# Epoch 00006: val_loss improved from 0.21938 to 0.21379, saving model to dataset/weights/TrainedModel_PyKeras.h5
# Epoch 7/20
# 300/300 [==============================] - 0s 1ms/step - loss: 0.2076 - accuracy: 0.9155 - val_loss: 0.2095 - val_accuracy: 0.9137
#
# Epoch 00007: val_loss improved from 0.21379 to 0.20950, saving model to dataset/weights/TrainedModel_PyKeras.h5
# Epoch 8/20
# 300/300 [==============================] - 0s 1ms/step - loss: 0.2042 - accuracy: 0.9169 - val_loss: 0.2065 - val_accuracy: 0.9158
#
# Epoch 00008: val_loss improved from 0.20950 to 0.20651, saving model to dataset/weights/TrainedModel_PyKeras.h5
# Epoch 9/20
# 300/300 [==============================] - 0s 1ms/step - loss: 0.2013 - accuracy: 0.9177 - val_loss: 0.2034 - val_accuracy: 0.9162
#
# Epoch 00009: val_loss improved from 0.20651 to 0.20340, saving model to dataset/weights/TrainedModel_PyKeras.h5
# Epoch 10/20
# 300/300 [==============================] - 0s 1ms/step - loss: 0.1989 - accuracy: 0.9193 - val_loss: 0.2011 - val_accuracy: 0.9175
#
# Epoch 00010: val_loss improved from 0.20340 to 0.20110, saving model to dataset/weights/TrainedModel_PyKeras.h5
# Epoch 11/20
# 300/300 [==============================] - 0s 1ms/step - loss: 0.1966 - accuracy: 0.9194 - val_loss: 0.1990 - val_accuracy: 0.9179
#
# Epoch 00011: val_loss improved from 0.20110 to 0.19895, saving model to dataset/weights/TrainedModel_PyKeras.h5
# Epoch 12/20
# 300/300 [==============================] - 0s 1ms/step - loss: 0.1947 - accuracy: 0.9201 - val_loss: 0.1972 - val_accuracy: 0.9183
#
# Epoch 00012: val_loss improved from 0.19895 to 0.19719, saving model to dataset/weights/TrainedModel_PyKeras.h5
# Epoch 13/20
# 300/300 [==============================] - 0s 1ms/step - loss: 0.1930 - accuracy: 0.9210 - val_loss: 0.1956 - val_accuracy: 0.9187
#
# Epoch 00013: val_loss improved from 0.19719 to 0.19565, saving model to dataset/weights/TrainedModel_PyKeras.h5
# Epoch 14/20
# 300/300 [==============================] - 0s 1ms/step - loss: 0.1914 - accuracy: 0.9216 - val_loss: 0.1950 - val_accuracy: 0.9183
#
# Epoch 00014: val_loss improved from 0.19565 to 0.19496, saving model to dataset/weights/TrainedModel_PyKeras.h5
# Epoch 15/20
# 300/300 [==============================] - 0s 1ms/step - loss: 0.1899 - accuracy: 0.9226 - val_loss: 0.1937 - val_accuracy: 0.9175
#
# Epoch 00015: val_loss improved from 0.19496 to 0.19370, saving model to dataset/weights/TrainedModel_PyKeras.h5
# Epoch 16/20
# 300/300 [==============================] - 0s 1ms/step - loss: 0.1887 - accuracy: 0.9225 - val_loss: 0.1923 - val_accuracy: 0.9204
#
# Epoch 00016: val_loss improved from 0.19370 to 0.19233, saving model to dataset/weights/TrainedModel_PyKeras.h5
# Epoch 17/20
# 300/300 [==============================] - 0s 1ms/step - loss: 0.1874 - accuracy: 0.9227 - val_loss: 0.1907 - val_accuracy: 0.9217
#
# Epoch 00017: val_loss improved from 0.19233 to 0.19073, saving model to dataset/weights/TrainedModel_PyKeras.h5
# Epoch 18/20
# 300/300 [==============================] - 0s 1ms/step - loss: 0.1864 - accuracy: 0.9228 - val_loss: 0.1898 - val_accuracy: 0.9208
#
# Epoch 00018: val_loss improved from 0.19073 to 0.18984, saving model to dataset/weights/TrainedModel_PyKeras.h5
# Epoch 19/20
# 300/300 [==============================] - 0s 1ms/step - loss: 0.1853 - accuracy: 0.9226 - val_loss: 0.1892 - val_accuracy: 0.9242
#
# Epoch 00019: val_loss improved from 0.18984 to 0.18918, saving model to dataset/weights/TrainedModel_PyKeras.h5
# Epoch 20/20
# 300/300 [==============================] - 0s 1ms/step - loss: 0.1843 - accuracy: 0.9240 - val_loss: 0.1883 - val_accuracy: 0.9229
#
# Epoch 00020: val_loss improved from 0.18918 to 0.18831, saving model to dataset/weights/TrainedModel_PyKeras.h5
# Factory                  : Train all methods
# Factory                  : [dataset] : Create Transformation "D" with events from all classes.
#                          :
#                          : Transformation, Variable selection :
#                          : Input : variable 'nhits' <---> Output : variable 'nhits'
#                          : Input : variable 'residual' <---> Output : variable 'residual'
#                          : Input : variable 'r' <---> Output : variable 'r'
#                          : Input : variable 'S0rawPerp' <---> Output : variable 'S0rawPerp'
#                          : Input : variable 'S0axisrawZ' <---> Output : variable 'S0axisrawZ'
#                          : Input : variable 'phi_S0axisraw' <---> Output : variable 'phi_S0axisraw'
#                          : Input : variable 'nCT' <---> Output : variable 'nCT'
#                          : Input : variable 'nGT' <---> Output : variable 'nGT'
#                          : Input : variable 'tracksdca' <---> Output : variable 'tracksdca'
#                          : Input : variable 'curvemin' <---> Output : variable 'curvemin'
#                          : Input : variable 'curvemean' <---> Output : variable 'curvemean'
#                          : Input : variable 'lambdamin' <---> Output : variable 'lambdamin'
#                          : Input : variable 'lambdamean' <---> Output : variable 'lambdamean'
#                          : Input : variable 'curvesign' <---> Output : variable 'curvesign'
# Factory                  : [dataset] : Create Transformation "G" with events from all classes.
#                          :
#                          : Transformation, Variable selection :
#                          : Input : variable 'nhits' <---> Output : variable 'nhits'
#                          : Input : variable 'residual' <---> Output : variable 'residual'
#                          : Input : variable 'r' <---> Output : variable 'r'
#                          : Input : variable 'S0rawPerp' <---> Output : variable 'S0rawPerp'
#                          : Input : variable 'S0axisrawZ' <---> Output : variable 'S0axisrawZ'
#                          : Input : variable 'phi_S0axisraw' <---> Output : variable 'phi_S0axisraw'
#                          : Input : variable 'nCT' <---> Output : variable 'nCT'
#                          : Input : variable 'nGT' <---> Output : variable 'nGT'
#                          : Input : variable 'tracksdca' <---> Output : variable 'tracksdca'
#                          : Input : variable 'curvemin' <---> Output : variable 'curvemin'
#                          : Input : variable 'curvemean' <---> Output : variable 'curvemean'
#                          : Input : variable 'lambdamin' <---> Output : variable 'lambdamin'
#                          : Input : variable 'lambdamean' <---> Output : variable 'lambdamean'
#                          : Input : variable 'curvesign' <---> Output : variable 'curvesign'
#                          : Preparing the Decorrelation transformation...
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
#                          : Preparing the Gaussian transformation...
# TFHandler_Factory        :      Variable             Mean             RMS     [        Min             Max ]
#                          : ------------------------------------------------------------------------------------
#                          :         nhits:      -0.047857        0.99802   [        -2.0108         5.7307 ]
#                          :      residual:      0.0051526        0.99846   [        -3.2370         5.7307 ]
#                          :             r:      0.0049218        0.99744   [        -3.2368         5.7307 ]
#                          :     S0rawPerp:      0.0048848        0.99727   [        -3.2370         5.7307 ]
#                          :    S0axisrawZ:      0.0050763        0.99800   [        -3.2369         5.7307 ]
#                          : phi_S0axisraw:      0.0055781         1.0001   [        -3.2370         5.7307 ]
#                          :           nCT:      0.0055121        0.99982   [        -3.2369         5.7307 ]
#                          :           nGT:      0.0058543         1.0017   [        -3.2370         5.7307 ]
#                          :     tracksdca:      0.0050990        0.99853   [        -3.2370         5.7307 ]
#                          :      curvemin:      0.0047678        0.99701   [        -3.2370         5.7307 ]
#                          :     curvemean:      0.0055194         1.0002   [        -3.2370         5.7307 ]
#                          :     lambdamin:      0.0048860        0.99729   [        -3.2370         5.7307 ]
#                          :    lambdamean:      0.0050574        0.99821   [        -3.2370         5.7307 ]
#                          :     curvesign:      0.0055851         1.0003   [        -3.2370         5.7307 ]
#                          : ------------------------------------------------------------------------------------
# Factory                  : Train method: Fisher for Classification
#                          :
#                          : Preparing the Decorrelation transformation...
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
#                          : Preparing the Gaussian transformation...
# TFHandler_Fisher         :      Variable             Mean             RMS     [        Min             Max ]
#                          : ------------------------------------------------------------------------------------
#                          :         nhits:      -0.047857        0.99802   [        -2.0108         5.7307 ]
#                          :      residual:      0.0051526        0.99846   [        -3.2370         5.7307 ]
#                          :             r:      0.0049218        0.99744   [        -3.2368         5.7307 ]
#                          :     S0rawPerp:      0.0048848        0.99727   [        -3.2370         5.7307 ]
#                          :    S0axisrawZ:      0.0050763        0.99800   [        -3.2369         5.7307 ]
#                          : phi_S0axisraw:      0.0055781         1.0001   [        -3.2370         5.7307 ]
#                          :           nCT:      0.0055121        0.99982   [        -3.2369         5.7307 ]
#                          :           nGT:      0.0058543         1.0017   [        -3.2370         5.7307 ]
#                          :     tracksdca:      0.0050990        0.99853   [        -3.2370         5.7307 ]
#                          :      curvemin:      0.0047678        0.99701   [        -3.2370         5.7307 ]
#                          :     curvemean:      0.0055194         1.0002   [        -3.2370         5.7307 ]
#                          :     lambdamin:      0.0048860        0.99729   [        -3.2370         5.7307 ]
#                          :    lambdamean:      0.0050574        0.99821   [        -3.2370         5.7307 ]
#                          :     curvesign:      0.0055851         1.0003   [        -3.2370         5.7307 ]
#                          : ------------------------------------------------------------------------------------
# Fisher                   : Results for Fisher coefficients:
#                          : NOTE: The coefficients must be applied to TRANFORMED variables
#                          :   List of the transformation:
#                          :   -- Deco
#                          :   -- Gauss
#                          : -----------------------------
#                          :      Variable:   Coefficient:
#                          : -----------------------------
#                          :         nhits:        +0.486
#                          :      residual:        +0.600
#                          :             r:        -0.446
#                          :     S0rawPerp:        -0.329
#                          :    S0axisrawZ:        +0.015
#                          : phi_S0axisraw:        +0.101
#                          :           nCT:        +0.323
#                          :           nGT:        -0.012
#                          :     tracksdca:        +0.089
#                          :      curvemin:        -0.191
#                          :     curvemean:        -0.002
#                          :     lambdamin:        -0.219
#                          :    lambdamean:        +0.147
#                          :     curvesign:        -0.026
#                          :      (offset):        +0.023
#                          : -----------------------------
#                          : Elapsed time for training with 12000 events: 0.223 sec
# Fisher                   : [dataset] : Evaluation of Fisher on training sample (12000 events)
#                          : Elapsed time for evaluation of 12000 events: 0.109 sec
#                          : Creating xml weight file: dataset/weights/TMVAClassification_Fisher.weights.xml
#                          : Creating standalone class: dataset/weights/TMVAClassification_Fisher.class.C
# Factory                  : Training finished
#                          :
# Factory                  : Train method: PyKeras for Classification
#                          :
#                          :
#                          :
#                          :
#                          :
#                          :
#                          :
#                          :
#                          :
#                          :
#                          :
#                          :
#                          :
#                          :
#                          :
#                          :
#                          : Preparing the Decorrelation transformation...
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
# <WARNING>                : <GetSQRootMatrix> error in matrix diagonalization; printed S and B
#                          : Preparing the Gaussian transformation...
# TFHandler_PyKeras        :      Variable             Mean             RMS     [        Min             Max ]
#                          : ------------------------------------------------------------------------------------
#                          :         nhits:      -0.047857        0.99802   [        -2.0108         5.7307 ]
#                          :      residual:      0.0051526        0.99846   [        -3.2370         5.7307 ]
#                          :             r:      0.0049218        0.99744   [        -3.2368         5.7307 ]
#                          :     S0rawPerp:      0.0048848        0.99727   [        -3.2370         5.7307 ]
#                          :    S0axisrawZ:      0.0050763        0.99800   [        -3.2369         5.7307 ]
#                          : phi_S0axisraw:      0.0055781         1.0001   [        -3.2370         5.7307 ]
#                          :           nCT:      0.0055121        0.99982   [        -3.2369         5.7307 ]
#                          :           nGT:      0.0058543         1.0017   [        -3.2370         5.7307 ]
#                          :     tracksdca:      0.0050990        0.99853   [        -3.2370         5.7307 ]
#                          :      curvemin:      0.0047678        0.99701   [        -3.2370         5.7307 ]
#                          :     curvemean:      0.0055194         1.0002   [        -3.2370         5.7307 ]
#                          :     lambdamin:      0.0048860        0.99729   [        -3.2370         5.7307 ]
#                          :    lambdamean:      0.0050574        0.99821   [        -3.2370         5.7307 ]
#                          :     curvesign:      0.0055851         1.0003   [        -3.2370         5.7307 ]
#                          : ------------------------------------------------------------------------------------
# TFHandler_PyKeras        :      Variable             Mean             RMS     [        Min             Max ]
#                          : ------------------------------------------------------------------------------------
#                          :         nhits:      -0.047857        0.99802   [        -2.0108         5.7307 ]
#                          :      residual:      0.0051526        0.99846   [        -3.2370         5.7307 ]
#                          :             r:      0.0049218        0.99744   [        -3.2368         5.7307 ]
#                          :     S0rawPerp:      0.0048848        0.99727   [        -3.2370         5.7307 ]
#                          :    S0axisrawZ:      0.0050763        0.99800   [        -3.2369         5.7307 ]
#                          : phi_S0axisraw:      0.0055781         1.0001   [        -3.2370         5.7307 ]
#                          :           nCT:      0.0055121        0.99982   [        -3.2369         5.7307 ]
#                          :           nGT:      0.0058543         1.0017   [        -3.2370         5.7307 ]
#                          :     tracksdca:      0.0050990        0.99853   [        -3.2370         5.7307 ]
#                          :      curvemin:      0.0047678        0.99701   [        -3.2370         5.7307 ]
#                          :     curvemean:      0.0055194         1.0002   [        -3.2370         5.7307 ]
#                          :     lambdamin:      0.0048860        0.99729   [        -3.2370         5.7307 ]
#                          :    lambdamean:      0.0050574        0.99821   [        -3.2370         5.7307 ]
#                          :     curvesign:      0.0055851         1.0003   [        -3.2370         5.7307 ]
#                          : ------------------------------------------------------------------------------------
#                          :
#                          :
#                          :
#                          :
#                          :
#                          :
#                          :
#                          :
# PyKeras                  :
#                          :
#                          :
#                          :
# Factory                  : Training finished
#                          :
# Factory                  : Train method: Cuts for Classification
#                          :
# FitterBase               : <MCFitter> Sampling, please be patient ...
#                          : Elapsed time: 1.55 sec
#                          : -------------------------------------------------
# Cuts                     : Cut values for requested signal efficiency: 0.1
#                          : Corresponding background efficiency       : -0.1
#                          : Transformation applied to input variables : None
#                          : -------------------------------------------------
#                          : Cut[ 0]:     -1e+30 <         nhits <=          0
#                          : Cut[ 1]:          0 <      residual <=      1e+30
#                          : Cut[ 2]:     -1e+30 <             r <=          0
#                          : Cut[ 3]:     -1e+30 <     S0rawPerp <=          0
#                          : Cut[ 4]:          0 <    S0axisrawZ <=      1e+30
#                          : Cut[ 5]:          0 < phi_S0axisraw <=      1e+30
#                          : Cut[ 6]:          0 <           nCT <=      1e+30
#                          : Cut[ 7]:          0 <           nGT <=      1e+30
#                          : Cut[ 8]:          0 <     tracksdca <=      1e+30
#                          : Cut[ 9]:     -1e+30 <      curvemin <=          0
#                          : Cut[10]:          0 <     curvemean <=      1e+30
#                          : Cut[11]:     -1e+30 <     lambdamin <=          0
#                          : Cut[12]:          0 <    lambdamean <=      1e+30
#                          : Cut[13]:     -1e+30 <     curvesign <=          0
#                          : -------------------------------------------------
#                          : -------------------------------------------------
# Cuts                     : Cut values for requested signal efficiency: 0.2
#                          : Corresponding background efficiency       : -0.1
#                          : Transformation applied to input variables : None
#                          : -------------------------------------------------
#                          : Cut[ 0]:     -1e+30 <         nhits <=          0
#                          : Cut[ 1]:          0 <      residual <=      1e+30
#                          : Cut[ 2]:     -1e+30 <             r <=          0
#                          : Cut[ 3]:     -1e+30 <     S0rawPerp <=          0
#                          : Cut[ 4]:          0 <    S0axisrawZ <=      1e+30
#                          : Cut[ 5]:          0 < phi_S0axisraw <=      1e+30
#                          : Cut[ 6]:          0 <           nCT <=      1e+30
#                          : Cut[ 7]:          0 <           nGT <=      1e+30
#                          : Cut[ 8]:          0 <     tracksdca <=      1e+30
#                          : Cut[ 9]:     -1e+30 <      curvemin <=          0
#                          : Cut[10]:          0 <     curvemean <=      1e+30
#                          : Cut[11]:     -1e+30 <     lambdamin <=          0
#                          : Cut[12]:          0 <    lambdamean <=      1e+30
#                          : Cut[13]:     -1e+30 <     curvesign <=          0
#                          : -------------------------------------------------
#                          : -------------------------------------------------
# Cuts                     : Cut values for requested signal efficiency: 0.3
#                          : Corresponding background efficiency       : -0.1
#                          : Transformation applied to input variables : None
#                          : -------------------------------------------------
#                          : Cut[ 0]:     -1e+30 <         nhits <=          0
#                          : Cut[ 1]:          0 <      residual <=      1e+30
#                          : Cut[ 2]:     -1e+30 <             r <=          0
#                          : Cut[ 3]:     -1e+30 <     S0rawPerp <=          0
#                          : Cut[ 4]:          0 <    S0axisrawZ <=      1e+30
#                          : Cut[ 5]:          0 < phi_S0axisraw <=      1e+30
#                          : Cut[ 6]:          0 <           nCT <=      1e+30
#                          : Cut[ 7]:          0 <           nGT <=      1e+30
#                          : Cut[ 8]:          0 <     tracksdca <=      1e+30
#                          : Cut[ 9]:     -1e+30 <      curvemin <=          0
#                          : Cut[10]:          0 <     curvemean <=      1e+30
#                          : Cut[11]:     -1e+30 <     lambdamin <=          0
#                          : Cut[12]:          0 <    lambdamean <=      1e+30
#                          : Cut[13]:     -1e+30 <     curvesign <=          0
#                          : -------------------------------------------------
#                          : -------------------------------------------------
# Cuts                     : Cut values for requested signal efficiency: 0.4
#                          : Corresponding background efficiency       : -0.1
#                          : Transformation applied to input variables : None
#                          : -------------------------------------------------
#                          : Cut[ 0]:     -1e+30 <         nhits <=          0
#                          : Cut[ 1]:          0 <      residual <=      1e+30
#                          : Cut[ 2]:     -1e+30 <             r <=          0
#                          : Cut[ 3]:     -1e+30 <     S0rawPerp <=          0
#                          : Cut[ 4]:          0 <    S0axisrawZ <=      1e+30
#                          : Cut[ 5]:          0 < phi_S0axisraw <=      1e+30
#                          : Cut[ 6]:          0 <           nCT <=      1e+30
#                          : Cut[ 7]:          0 <           nGT <=      1e+30
#                          : Cut[ 8]:          0 <     tracksdca <=      1e+30
#                          : Cut[ 9]:     -1e+30 <      curvemin <=          0
#                          : Cut[10]:          0 <     curvemean <=      1e+30
#                          : Cut[11]:     -1e+30 <     lambdamin <=          0
#                          : Cut[12]:          0 <    lambdamean <=      1e+30
#                          : Cut[13]:     -1e+30 <     curvesign <=          0
#                          : -------------------------------------------------
#                          : -------------------------------------------------
# Cuts                     : Cut values for requested signal efficiency: 0.5
#                          : Corresponding background efficiency       : -0.1
#                          : Transformation applied to input variables : None
#                          : -------------------------------------------------
#                          : Cut[ 0]:     -1e+30 <         nhits <=          0
#                          : Cut[ 1]:          0 <      residual <=      1e+30
#                          : Cut[ 2]:     -1e+30 <             r <=          0
#                          : Cut[ 3]:     -1e+30 <     S0rawPerp <=          0
#                          : Cut[ 4]:          0 <    S0axisrawZ <=      1e+30
#                          : Cut[ 5]:          0 < phi_S0axisraw <=      1e+30
#                          : Cut[ 6]:          0 <           nCT <=      1e+30
#                          : Cut[ 7]:          0 <           nGT <=      1e+30
#                          : Cut[ 8]:          0 <     tracksdca <=      1e+30
#                          : Cut[ 9]:     -1e+30 <      curvemin <=          0
#                          : Cut[10]:          0 <     curvemean <=      1e+30
#                          : Cut[11]:     -1e+30 <     lambdamin <=          0
#                          : Cut[12]:          0 <    lambdamean <=      1e+30
#                          : Cut[13]:     -1e+30 <     curvesign <=          0
#                          : -------------------------------------------------
#                          : -------------------------------------------------
# Cuts                     : Cut values for requested signal efficiency: 0.6
#                          : Corresponding background efficiency       : -0.1
#                          : Transformation applied to input variables : None
#                          : -------------------------------------------------
#                          : Cut[ 0]:     -1e+30 <         nhits <=          0
#                          : Cut[ 1]:          0 <      residual <=      1e+30
#                          : Cut[ 2]:     -1e+30 <             r <=          0
#                          : Cut[ 3]:     -1e+30 <     S0rawPerp <=          0
#                          : Cut[ 4]:          0 <    S0axisrawZ <=      1e+30
#                          : Cut[ 5]:          0 < phi_S0axisraw <=      1e+30
#                          : Cut[ 6]:          0 <           nCT <=      1e+30
#                          : Cut[ 7]:          0 <           nGT <=      1e+30
#                          : Cut[ 8]:          0 <     tracksdca <=      1e+30
#                          : Cut[ 9]:     -1e+30 <      curvemin <=          0
#                          : Cut[10]:          0 <     curvemean <=      1e+30
#                          : Cut[11]:     -1e+30 <     lambdamin <=          0
#                          : Cut[12]:          0 <    lambdamean <=      1e+30
#                          : Cut[13]:     -1e+30 <     curvesign <=          0
#                          : -------------------------------------------------
#                          : -------------------------------------------------
# Cuts                     : Cut values for requested signal efficiency: 0.7
#                          : Corresponding background efficiency       : -0.1
#                          : Transformation applied to input variables : None
#                          : -------------------------------------------------
#                          : Cut[ 0]:     -1e+30 <         nhits <=          0
#                          : Cut[ 1]:          0 <      residual <=      1e+30
#                          : Cut[ 2]:     -1e+30 <             r <=          0
#                          : Cut[ 3]:     -1e+30 <     S0rawPerp <=          0
#                          : Cut[ 4]:          0 <    S0axisrawZ <=      1e+30
#                          : Cut[ 5]:          0 < phi_S0axisraw <=      1e+30
#                          : Cut[ 6]:          0 <           nCT <=      1e+30
#                          : Cut[ 7]:          0 <           nGT <=      1e+30
#                          : Cut[ 8]:          0 <     tracksdca <=      1e+30
#                          : Cut[ 9]:     -1e+30 <      curvemin <=          0
#                          : Cut[10]:          0 <     curvemean <=      1e+30
#                          : Cut[11]:     -1e+30 <     lambdamin <=          0
#                          : Cut[12]:          0 <    lambdamean <=      1e+30
#                          : Cut[13]:     -1e+30 <     curvesign <=          0
#                          : -------------------------------------------------
#                          : -------------------------------------------------
# Cuts                     : Cut values for requested signal efficiency: 0.8
#                          : Corresponding background efficiency       : -0.1
#                          : Transformation applied to input variables : None
#                          : -------------------------------------------------
#                          : Cut[ 0]:     -1e+30 <         nhits <=          0
#                          : Cut[ 1]:          0 <      residual <=      1e+30
#                          : Cut[ 2]:     -1e+30 <             r <=          0
#                          : Cut[ 3]:     -1e+30 <     S0rawPerp <=          0
#                          : Cut[ 4]:          0 <    S0axisrawZ <=      1e+30
#                          : Cut[ 5]:          0 < phi_S0axisraw <=      1e+30
#                          : Cut[ 6]:          0 <           nCT <=      1e+30
#                          : Cut[ 7]:          0 <           nGT <=      1e+30
#                          : Cut[ 8]:          0 <     tracksdca <=      1e+30
#                          : Cut[ 9]:     -1e+30 <      curvemin <=          0
#                          : Cut[10]:          0 <     curvemean <=      1e+30
#                          : Cut[11]:     -1e+30 <     lambdamin <=          0
#                          : Cut[12]:          0 <    lambdamean <=      1e+30
#                          : Cut[13]:     -1e+30 <     curvesign <=          0
#                          : -------------------------------------------------
#                          : -------------------------------------------------
# Cuts                     : Cut values for requested signal efficiency: 0.9
#                          : Corresponding background efficiency       : -0.1
#                          : Transformation applied to input variables : None
#                          : -------------------------------------------------
#                          : Cut[ 0]:     -1e+30 <         nhits <=          0
#                          : Cut[ 1]:          0 <      residual <=      1e+30
#                          : Cut[ 2]:     -1e+30 <             r <=          0
#                          : Cut[ 3]:     -1e+30 <     S0rawPerp <=          0
#                          : Cut[ 4]:          0 <    S0axisrawZ <=      1e+30
#                          : Cut[ 5]:          0 < phi_S0axisraw <=      1e+30
#                          : Cut[ 6]:          0 <           nCT <=      1e+30
#                          : Cut[ 7]:          0 <           nGT <=      1e+30
#                          : Cut[ 8]:          0 <     tracksdca <=      1e+30
#                          : Cut[ 9]:     -1e+30 <      curvemin <=          0
#                          : Cut[10]:          0 <     curvemean <=      1e+30
#                          : Cut[11]:     -1e+30 <     lambdamin <=          0
#                          : Cut[12]:          0 <    lambdamean <=      1e+30
#                          : Cut[13]:     -1e+30 <     curvesign <=          0
#                          : -------------------------------------------------
#                          : Elapsed time for training with 12000 events: 1.57 sec
# Cuts                     : [dataset] : Evaluation of Cuts on training sample (12000 events)
#                          : Elapsed time for evaluation of 12000 events: 0.00124 sec
#                          : Creating xml weight file: dataset/weights/TMVAClassification_Cuts.weights.xml
#                          : Creating standalone class: dataset/weights/TMVAClassification_Cuts.class.C
#                          : TMVA.root:/dataset/Method_Cuts/Cuts
# Factory                  : Training finished
#                          :
# Factory                  : Train method: KNN for Classification
#                          :
# KNN                      : <Train> start...
#                          : Reading 12000 events
#                          : Number of signal events 6000
#                          : Number of background events 6000
#                          : Creating kd-tree with 12000 events
#                          : Computing scale factor for 1d distributions: (ifrac, bottom, top) = (80%, 10%, 90%)
# ModulekNN                : Optimizing tree for 14 variables with 12000 values
#                          : <Fill> Class 1 has     6000 events
#                          : <Fill> Class 2 has     6000 events
#                          : Elapsed time for training with 12000 events: 0.049 sec
# KNN                      : [dataset] : Evaluation of KNN on training sample (12000 events)
#                          : Elapsed time for evaluation of 12000 events: 3.56 sec
#                          : Creating xml weight file: dataset/weights/TMVAClassification_KNN.weights.xml
#                          : Creating standalone class: dataset/weights/TMVAClassification_KNN.class.C
# Factory                  : Training finished
#                          :
# Factory                  : Train method: SVM for Classification
#                          :
# TFHandler_SVM            :      Variable             Mean             RMS     [        Min             Max ]
#                          : ------------------------------------------------------------------------------------
#                          :         nhits:       -0.99877       0.038890   [        -1.0000         1.0000 ]
#                          :      residual:       -0.90474        0.14401   [        -1.0000         1.0000 ]
#                          :             r:       -0.85971        0.13736   [        -1.0000         1.0000 ]
#                          :     S0rawPerp:        0.52309        0.55683   [        -1.0000         1.0000 ]
#                          :    S0axisrawZ:        0.84943        0.49169   [        -1.0000         1.0000 ]
#                          : phi_S0axisraw:       -0.10207        0.65652   [        -1.0000         1.0000 ]
#                          :           nCT:       -0.64524        0.24768   [        -1.0000         1.0000 ]
#                          :           nGT:       -0.68967        0.22537   [        -1.0000         1.0000 ]
#                          :     tracksdca:       -0.90739        0.18299   [        -1.0000         1.0000 ]
#                          :      curvemin:       -0.86800        0.49656   [        -1.0000         1.0000 ]
#                          :     curvemean:       -0.87439        0.16638   [        -1.0000         1.0000 ]
#                          :     lambdamin:       -0.86794        0.49655   [        -1.0000         1.0000 ]
#                          :    lambdamean:       -0.60878        0.29845   [        -1.0000         1.0000 ]
#                          :     curvesign:      0.0030208        0.17212   [        -1.0000         1.0000 ]
#                          : ------------------------------------------------------------------------------------
#                          : Building SVM Working Set...with 12000 event instances
#                          : Elapsed time for Working Set build: 5.68 sec
#                          : Sorry, no computing time forecast available for SVM, please wait ...
#                          : Elapsed time: 39.5 sec
#                          : Elapsed time for training with 12000 events: 45.3 sec
# SVM                      : [dataset] : Evaluation of SVM on training sample (12000 events)
#                          : Elapsed time for evaluation of 12000 events: 1.82 sec
#                          : Creating xml weight file: dataset/weights/TMVAClassification_SVM.weights.xml
#                          : Creating standalone class: dataset/weights/TMVAClassification_SVM.class.C
# Factory                  : Training finished
#                          :
# Factory                  : Train method: BDT for Classification
#                          :
# BDT                      : #events: (reweighted) sig: 6000 bkg: 6000
#                          : #events: (unweighted) sig: 6000 bkg: 6000
#                          : Training 850 Decision Trees ... patience please
#                          : Elapsed time for training with 12000 events: 6.92 sec
# BDT                      : [dataset] : Evaluation of BDT on training sample (12000 events)
#                          : Elapsed time for evaluation of 12000 events: 0.927 sec
#                          : Creating xml weight file: dataset/weights/TMVAClassification_BDT.weights.xml
#                          : Creating standalone class: dataset/weights/TMVAClassification_BDT.class.C
#                          : TMVA.root:/dataset/Method_BDT/BDT
# Factory                  : Training finished
#                          :
# Factory                  : Train method: BDTB for Classification
#                          :
# BDTB                     : #events: (reweighted) sig: 6000 bkg: 6000
#                          : #events: (unweighted) sig: 6000 bkg: 6000
#                          : Training 500 Decision Trees ... patience please
#                          : Elapsed time for training with 12000 events: 5 sec
# BDTB                     : [dataset] : Evaluation of BDTB on training sample (12000 events)
#                          : Elapsed time for evaluation of 12000 events: 0.557 sec
#                          : <CreateMVAPdfs> Separation from histogram (PDF): 0.844 (0.000)
#                          : Dataset[dataset] : Evaluation of BDTB on training sample
#                          : Creating xml weight file: dataset/weights/TMVAClassification_BDTB.weights.xml
#                          : Creating standalone class: dataset/weights/TMVAClassification_BDTB.class.C
#                          : TMVA.root:/dataset/Method_BDT/BDTB
# Factory                  : Training finished
#                          :
# Factory                  : Train method: BDTG for Classification
#                          :
# BDTG                     : #events: (reweighted) sig: 6000 bkg: 6000
#                          : #events: (unweighted) sig: 6000 bkg: 6000
#                          : Training 1000 Decision Trees ... patience please
#                          : Elapsed time for training with 12000 events: 8.2 sec
# BDTG                     : [dataset] : Evaluation of BDTG on training sample (12000 events)
#                          : Elapsed time for evaluation of 12000 events: 0.645 sec
#                          : Creating xml weight file: dataset/weights/TMVAClassification_BDTG.weights.xml
#                          : Creating standalone class: dataset/weights/TMVAClassification_BDTG.class.C
#                          : TMVA.root:/dataset/Method_BDT/BDTG
# Factory                  : Training finished
#                          :
#                          : Ranking input variables (method specific)...
# Fisher                   : Ranking result (top variable is best ranked)
#                          : ----------------------------------------
#                          : Rank : Variable      : Discr. power
#                          : ----------------------------------------
#                          :    1 : nhits         : 2.462e-01
#                          :    2 : residual      : 1.244e-01
#                          :    3 : nCT           : 6.900e-02
#                          :    4 : S0rawPerp     : 4.365e-02
#                          :    5 : lambdamin     : 2.051e-02
#                          :    6 : r             : 1.775e-02
#                          :    7 : curvesign     : 6.610e-03
#                          :    8 : lambdamean    : 2.504e-03
#                          :    9 : curvemin      : 1.711e-03
#                          :   10 : phi_S0axisraw : 1.152e-03
#                          :   11 : curvemean     : 5.523e-04
#                          :   12 : nGT           : 1.789e-04
#                          :   13 : tracksdca     : 3.404e-05
#                          :   14 : S0axisrawZ    : 1.377e-08
#                          : ----------------------------------------
#                          : No variable ranking supplied by classifier: PyKeras
#                          : No variable ranking supplied by classifier: Cuts
#                          : No variable ranking supplied by classifier: KNN
#                          : No variable ranking supplied by classifier: SVM
# BDT                      : Ranking result (top variable is best ranked)
#                          : -----------------------------------------------
#                          : Rank : Variable      : Variable Importance
#                          : -----------------------------------------------
#                          :    1 : phi_S0axisraw : 1.320e-01
#                          :    2 : lambdamean    : 1.118e-01
#                          :    3 : S0rawPerp     : 9.449e-02
#                          :    4 : curvemean     : 9.189e-02
#                          :    5 : residual      : 7.947e-02
#                          :    6 : r             : 7.735e-02
#                          :    7 : nhits         : 6.923e-02
#                          :    8 : curvesign     : 6.887e-02
#                          :    9 : S0axisrawZ    : 6.347e-02
#                          :   10 : nCT           : 5.631e-02
#                          :   11 : curvemin      : 4.646e-02
#                          :   12 : tracksdca     : 4.455e-02
#                          :   13 : lambdamin     : 4.296e-02
#                          :   14 : nGT           : 2.107e-02
#                          : -----------------------------------------------
# BDTB                     : Ranking result (top variable is best ranked)
#                          : -----------------------------------------------
#                          : Rank : Variable      : Variable Importance
#                          : -----------------------------------------------
#                          :    1 : phi_S0axisraw : 1.102e-01
#                          :    2 : lambdamean    : 1.022e-01
#                          :    3 : residual      : 8.685e-02
#                          :    4 : curvemean     : 8.483e-02
#                          :    5 : S0rawPerp     : 8.171e-02
#                          :    6 : S0axisrawZ    : 7.807e-02
#                          :    7 : nhits         : 7.450e-02
#                          :    8 : r             : 6.926e-02
#                          :    9 : curvesign     : 6.097e-02
#                          :   10 : lambdamin     : 5.811e-02
#                          :   11 : tracksdca     : 5.539e-02
#                          :   12 : nCT           : 5.310e-02
#                          :   13 : curvemin      : 4.778e-02
#                          :   14 : nGT           : 3.696e-02
#                          : -----------------------------------------------
# BDTG                     : Ranking result (top variable is best ranked)
#                          : -----------------------------------------------
#                          : Rank : Variable      : Variable Importance
#                          : -----------------------------------------------
#                          :    1 : curvemean     : 1.409e-01
#                          :    2 : lambdamean    : 1.127e-01
#                          :    3 : phi_S0axisraw : 9.644e-02
#                          :    4 : r             : 9.533e-02
#                          :    5 : S0rawPerp     : 8.525e-02
#                          :    6 : residual      : 7.082e-02
#                          :    7 : nCT           : 6.410e-02
#                          :    8 : curvesign     : 5.712e-02
#                          :    9 : nhits         : 5.430e-02
#                          :   10 : tracksdca     : 5.059e-02
#                          :   11 : nGT           : 4.833e-02
#                          :   12 : curvemin      : 4.818e-02
#                          :   13 : lambdamin     : 4.117e-02
#                          :   14 : S0axisrawZ    : 3.480e-02
#                          : -----------------------------------------------
# TH1.Print Name  = TrainingHistory_PyKeras_'accuracy', Entries= 0, Total sum= 18.2696
# TH1.Print Name  = TrainingHistory_PyKeras_'loss', Entries= 0, Total sum= 4.31851
# TH1.Print Name  = TrainingHistory_PyKeras_'val_accuracy', Entries= 0, Total sum= 18.3283
# TH1.Print Name  = TrainingHistory_PyKeras_'val_loss', Entries= 0, Total sum= 4.20979
# Factory                  : === Destroy and recreate all methods via weight files for testing ===
#                          :
#                          : Reading weight file: dataset/weights/TMVAClassification_Fisher.weights.xml
#                          : Reading weight file: dataset/weights/TMVAClassification_PyKeras.weights.xml
#                          : Reading weight file: dataset/weights/TMVAClassification_Cuts.weights.xml
#                          : Read cuts optimised using sample of MC events
#                          : Reading 100 signal efficiency bins for 14 variables
#                          : Reading weight file: dataset/weights/TMVAClassification_KNN.weights.xml
#                          : Creating kd-tree with 12000 events
#                          : Computing scale factor for 1d distributions: (ifrac, bottom, top) = (80%, 10%, 90%)
# ModulekNN                : Optimizing tree for 14 variables with 12000 values
#                          : <Fill> Class 1 has     6000 events
#                          : <Fill> Class 2 has     6000 events
#                          : Reading weight file: dataset/weights/TMVAClassification_SVM.weights.xml
#                          : Reading weight file: dataset/weights/TMVAClassification_BDT.weights.xml
#                          : Reading weight file: dataset/weights/TMVAClassification_BDTB.weights.xml
#                          : Reading weight file: dataset/weights/TMVAClassification_BDTG.weights.xml
# 0%, time left: unknown
# 7%, time left: 0 sec
# 13%, time left: 0 sec
# 19%, time left: 0 sec
# 25%, time left: 0 sec
# 32%, time left: 0 sec
# 38%, time left: 0 sec
# 44%, time left: 0 sec
# 50%, time left: 0 sec
# 57%, time left: 0 sec
# 63%, time left: 0 sec
# 69%, time left: 0 sec
# 75%, time left: 0 sec
# 82%, time left: 0 sec
# 88%, time left: 0 sec
# 94%, time left: 0 sec
# 2022-02-08 14:24:55.491681: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-02-08 14:24:55.494322: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2399930000 Hz
# 0%, time left: unknown
# 7%, time left: 1 sec
# 13%, time left: 1 sec
# 19%, time left: 1 sec
# 25%, time left: 1 sec
# 32%, time left: 1 sec
# 38%, time left: 0 sec
# 44%, time left: 0 sec
# 50%, time left: 0 sec
# 57%, time left: 0 sec
# 63%, time left: 0 sec
# 69%, time left: 0 sec
# 75%, time left: 0 sec
# 82%, time left: 0 sec
# 88%, time left: 0 sec
# 94%, time left: 0 sec
# 0%, time left: unknown
# 7%, time left: 0 sec
# 13%, time left: 0 sec
# 19%, time left: 0 sec
# 25%, time left: 0 sec
# 32%, time left: 0 sec
# 38%, time left: 0 sec
# 44%, time left: 0 sec
# 50%, time left: 0 sec
# 57%, time left: 0 sec
# 63%, time left: 0 sec
# 69%, time left: 0 sec
# 75%, time left: 0 sec
# 82%, time left: 0 sec
# 88%, time left: 0 sec
# 94%, time left: 0 sec
# 0%, time left: unknown
# 7%, time left: 3 sec
# 13%, time left: 3 sec
# 19%, time left: 2 sec
# 25%, time left: 2 sec
# 32%, time left: 2 sec
# 38%, time left: 2 sec
# 44%, time left: 2 sec
# 50%, time left: 1 sec
# 57%, time left: 1 sec
# 63%, time left: 1 sec
# 69%, time left: 1 sec
# 75%, time left: 0 sec
# 82%, time left: 0 sec
# 88%, time left: 0 sec
# 94%, time left: 0 sec
# 0%, time left: unknown
# 7%, time left: 1 sec
# 13%, time left: 1 sec
# 19%, time left: 1 sec
# 25%, time left: 1 sec
# 32%, time left: 1 sec
# 38%, time left: 1 sec
# 44%, time left: 1 sec
# 50%, time left: 0 sec
# 57%, time left: 0 sec
# 63%, time left: 0 sec
# 69%, time left: 0 sec
# 75%, time left: 0 sec
# 82%, time left: 0 sec
# 88%, time left: 0 sec
# 94%, time left: 0 sec
# 0%, time left: unknown
# 6%, time left: 5 sec
# 12%, time left: 5 sec
# 18%, time left: 4 sec
# 25%, time left: 4 sec
# 31%, time left: 4 sec
# 37%, time left: 3 sec
# 43%, time left: 3 sec
# 50%, time left: 3 sec
# 56%, time left: 2 sec
# 62%, time left: 2 sec
# 68%, time left: 2 sec
# 75%, time left: 1 sec
# 81%, time left: 1 sec
# 87%, time left: 0 sec
# 93%, time left: 0 sec
# 0%, time left: unknown
# 7%, time left: 0 sec
# 13%, time left: 0 sec
# 19%, time left: 0 sec
# 25%, time left: 0 sec
# 32%, time left: 0 sec
# 38%, time left: 0 sec
# 44%, time left: 0 sec
# 50%, time left: 0 sec
# 57%, time left: 0 sec
# 63%, time left: 0 sec
# 69%, time left: 0 sec
# 75%, time left: 0 sec
# 82%, time left: 0 sec
# 88%, time left: 0 sec
# 94%, time left: 0 sec
# 0%, time left: unknown
# 6%, time left: 4 sec
# 12%, time left: 4 sec
# 19%, time left: 4 sec
# 25%, time left: 3 sec
# 31%, time left: 3 sec
# 37%, time left: 3 sec
# 44%, time left: 2 sec
# 50%, time left: 2 sec
# 56%, time left: 2 sec
# 62%, time left: 1 sec
# 69%, time left: 1 sec
# 75%, time left: 1 sec
# 81%, time left: 0 sec
# 87%, time left: 0 sec
# 94%, time left: 0 sec
# 0%, time left: unknown
# 7%, time left: 0 sec
# 13%, time left: 0 sec
# 19%, time left: 0 sec
# 25%, time left: 0 sec
# 32%, time left: 0 sec
# 38%, time left: 0 sec
# 44%, time left: 0 sec
# 50%, time left: 0 sec
# 57%, time left: 0 sec
# 63%, time left: 0 sec
# 69%, time left: 0 sec
# 75%, time left: 0 sec
# 82%, time left: 0 sec
# 88%, time left: 0 sec
# 94%, time left: 0 sec
# 0%, time left: unknown
# 7%, time left: 0 sec
# 13%, time left: 0 sec
# 19%, time left: 0 sec
# 25%, time left: 0 sec
# 32%, time left: 0 sec
# 38%, time left: 0 sec
# 44%, time left: 0 sec
# 50%, time left: 0 sec
# 57%, time left: 0 sec
# 63%, time left: 0 sec
# 69%, time left: 0 sec
# 75%, time left: 0 sec
# 82%, time left: 0 sec
# 88%, time left: 0 sec
# 94%, time left: 0 sec
# 0%, time left: unknown
# 6%, time left: 9 sec
# 12%, time left: 8 sec
# 18%, time left: 7 sec
# 25%, time left: 6 sec
# 31%, time left: 5 sec
# 37%, time left: 5 sec
# 43%, time left: 4 sec
# 50%, time left: 4 sec
# 56%, time left: 3 sec
# 62%, time left: 3 sec
# 68%, time left: 2 sec
# 75%, time left: 1 sec
# 81%, time left: 1 sec
# 87%, time left: 1 sec
# 93%, time left: 0 sec
# 0%, time left: unknown
# 7%, time left: 0 sec
# 13%, time left: 0 sec
# 19%, time left: 0 sec
# 25%, time left: 0 sec
# 32%, time left: 0 sec
# 38%, time left: 0 sec
# 44%, time left: 0 sec
# 50%, time left: 0 sec
# 57%, time left: 0 sec
# 63%, time left: 0 sec
# 69%, time left: 0 sec
# 75%, time left: 0 sec
# 82%, time left: 0 sec
# 88%, time left: 0 sec
# 94%, time left: 0 sec

# %%
factory.TestAllMethods()
# Out:
# Factory                  : Test all methods
# Factory                  : Test method: Fisher for Classification performance
#                          :
# Fisher                   : [dataset] : Evaluation of Fisher on testing sample (8000 events)
#                          : Elapsed time for evaluation of 8000 events: 0.0718 sec
# Factory                  : Test method: PyKeras for Classification performance
#                          :
#                          : Setting up tf.keras
#                          : Using TensorFlow version 2
#                          : Use Keras version from TensorFlow : tf.keras
#                          :  Loading Keras Model
#                          : Loaded model from file: dataset/weights/TrainedModel_PyKeras.h5
# PyKeras                  : [dataset] : Evaluation of PyKeras on testing sample (8000 events)
#                          : Elapsed time for evaluation of 8000 events: 0.318 sec
# Factory                  : Test method: Cuts for Classification performance
#                          :
# Cuts                     : [dataset] : Evaluation of Cuts on testing sample (8000 events)
#                          : Elapsed time for evaluation of 8000 events: 0.001 sec
# Factory                  : Test method: KNN for Classification performance
#                          :
# KNN                      : [dataset] : Evaluation of KNN on testing sample (8000 events)
#                          : Elapsed time for evaluation of 8000 events: 2.19 sec
# Factory                  : Test method: SVM for Classification performance
#                          :
# SVM                      : [dataset] : Evaluation of SVM on testing sample (8000 events)
#                          : Elapsed time for evaluation of 8000 events: 0.921 sec
# Factory                  : Test method: BDT for Classification performance
#                          :
# BDT                      : [dataset] : Evaluation of BDT on testing sample (8000 events)
#                          : Elapsed time for evaluation of 8000 events: 0.464 sec
# Factory                  : Test method: BDTB for Classification performance
#                          :
# BDTB                     : [dataset] : Evaluation of BDTB on testing sample (8000 events)
#                          : Elapsed time for evaluation of 8000 events: 0.297 sec
#                          : Dataset[dataset] : Evaluation of BDTB on testing sample
# Factory                  : Test method: BDTG for Classification performance
#                          :
# BDTG                     : [dataset] : Evaluation of BDTG on testing sample (8000 events)
#                          : Elapsed time for evaluation of 8000 events: 0.332 sec
# 0%, time left: unknown
# 7%, time left: 0 sec
# 13%, time left: 0 sec
# 19%, time left: 0 sec
# 25%, time left: 0 sec
# 32%, time left: 0 sec
# 38%, time left: 0 sec
# 44%, time left: 0 sec
# 50%, time left: 0 sec
# 57%, time left: 0 sec
# 63%, time left: 0 sec
# 69%, time left: 0 sec
# 75%, time left: 0 sec
# 82%, time left: 0 sec
# 88%, time left: 0 sec
# 94%, time left: 0 sec
# 0%, time left: unknown
# 7%, time left: 0 sec
# 13%, time left: 0 sec
# 19%, time left: 0 sec
# 25%, time left: 0 sec
# 32%, time left: 0 sec
# 38%, time left: 0 sec
# 44%, time left: 0 sec
# 50%, time left: 0 sec
# 57%, time left: 0 sec
# 63%, time left: 0 sec
# 69%, time left: 0 sec
# 75%, time left: 0 sec
# 82%, time left: 0 sec
# 88%, time left: 0 sec
# 94%, time left: 0 sec
# 0%, time left: unknown
# 7%, time left: 2 sec
# 13%, time left: 2 sec
# 19%, time left: 1 sec
# 25%, time left: 1 sec
# 32%, time left: 1 sec
# 38%, time left: 1 sec
# 44%, time left: 1 sec
# 50%, time left: 1 sec
# 57%, time left: 0 sec
# 63%, time left: 0 sec
# 69%, time left: 0 sec
# 75%, time left: 0 sec
# 82%, time left: 0 sec
# 88%, time left: 0 sec
# 94%, time left: 0 sec
# 0%, time left: unknown
# 7%, time left: 0 sec
# 13%, time left: 0 sec
# 19%, time left: 0 sec
# 25%, time left: 0 sec
# 32%, time left: 0 sec
# 38%, time left: 0 sec
# 44%, time left: 0 sec
# 50%, time left: 0 sec
# 57%, time left: 0 sec
# 63%, time left: 0 sec
# 69%, time left: 0 sec
# 75%, time left: 0 sec
# 82%, time left: 0 sec
# 88%, time left: 0 sec
# 94%, time left: 0 sec
# 0%, time left: unknown
# 7%, time left: 0 sec
# 13%, time left: 0 sec
# 19%, time left: 0 sec
# 25%, time left: 0 sec
# 32%, time left: 0 sec
# 38%, time left: 0 sec
# 44%, time left: 0 sec
# 50%, time left: 0 sec
# 57%, time left: 0 sec
# 63%, time left: 0 sec
# 69%, time left: 0 sec
# 75%, time left: 0 sec
# 82%, time left: 0 sec
# 88%, time left: 0 sec
# 94%, time left: 0 sec
# 0%, time left: unknown
# 7%, time left: 0 sec
# 13%, time left: 0 sec
# 19%, time left: 0 sec
# 25%, time left: 0 sec
# 32%, time left: 0 sec
# 38%, time left: 0 sec
# 44%, time left: 0 sec
# 50%, time left: 0 sec
# 57%, time left: 0 sec
# 63%, time left: 0 sec
# 69%, time left: 0 sec
# 75%, time left: 0 sec
# 82%, time left: 0 sec
# 88%, time left: 0 sec
# 94%, time left: 0 sec
# 0%, time left: unknown
# 7%, time left: 0 sec
# 13%, time left: 0 sec
# 19%, time left: 0 sec
# 25%, time left: 0 sec
# 32%, time left: 0 sec
# 38%, time left: 0 sec
# 44%, time left: 0 sec
# 50%, time left: 0 sec
# 57%, time left: 0 sec
# 63%, time left: 0 sec
# 69%, time left: 0 sec
# 75%, time left: 0 sec
# 82%, time left: 0 sec
# 88%, time left: 0 sec
# 94%, time left: 0 sec
# 0%, time left: unknown
# 7%, time left: 0 sec
# 13%, time left: 0 sec
# 19%, time left: 0 sec
# 25%, time left: 0 sec
# 32%, time left: 0 sec
# 38%, time left: 0 sec
# 44%, time left: 0 sec
# 50%, time left: 0 sec
# 57%, time left: 0 sec
# 63%, time left: 0 sec
# 69%, time left: 0 sec
# 75%, time left: 0 sec
# 82%, time left: 0 sec
# 88%, time left: 0 sec
# 94%, time left: 0 sec

# %%
factory.EvaluateAllMethods()
# Out:
# Factory                  : Evaluate all methods
# Factory                  : Evaluate classifier: Fisher
#                          :
# TFHandler_Fisher         :      Variable             Mean             RMS     [        Min             Max ]
#                          : ------------------------------------------------------------------------------------
#                          :         nhits:      -0.067373        0.98861   [        -2.0098         5.7307 ]
#                          :      residual:      0.0050044         1.0109   [        -4.3770         3.8136 ]
#                          :             r:      0.0048427         1.0168   [        -5.7307         5.7307 ]
#                          :     S0rawPerp:      -0.020035         1.0023   [        -5.7307         3.6124 ]
#                          :    S0axisrawZ:       0.012440         1.0089   [        -2.9285         5.7307 ]
#                          : phi_S0axisraw:     -0.0034774        0.98613   [        -3.6364         3.4607 ]
#                          :           nCT:     -0.0031929         1.0006   [        -2.9311         3.6537 ]
#                          :           nGT:      -0.014713        0.98657   [        -3.2290         5.7307 ]
#                          :     tracksdca:      0.0055572        0.99641   [        -2.9051         5.7307 ]
#                          :      curvemin:      0.0075358         1.0067   [        -5.7307         3.5857 ]
#                          :     curvemean:      -0.014375        0.99615   [        -3.3701         5.7307 ]
#                          :     lambdamin:       0.022959         1.0117   [        -2.9579         5.7307 ]
#                          :    lambdamean:       0.020850         1.0043   [        -3.0098         5.7307 ]
#                          :     curvesign:       0.020685        0.98152   [        -3.0186         5.7307 ]
#                          : ------------------------------------------------------------------------------------
# Fisher                   : [dataset] : Loop over test events and fill histograms with classifier response...
#                          :
# TFHandler_Fisher         :      Variable             Mean             RMS     [        Min             Max ]
#                          : ------------------------------------------------------------------------------------
#                          :         nhits:      -0.067373        0.98861   [        -2.0098         5.7307 ]
#                          :      residual:      0.0050044         1.0109   [        -4.3770         3.8136 ]
#                          :             r:      0.0048427         1.0168   [        -5.7307         5.7307 ]
#                          :     S0rawPerp:      -0.020035         1.0023   [        -5.7307         3.6124 ]
#                          :    S0axisrawZ:       0.012440         1.0089   [        -2.9285         5.7307 ]
#                          : phi_S0axisraw:     -0.0034774        0.98613   [        -3.6364         3.4607 ]
#                          :           nCT:     -0.0031929         1.0006   [        -2.9311         3.6537 ]
#                          :           nGT:      -0.014713        0.98657   [        -3.2290         5.7307 ]
#                          :     tracksdca:      0.0055572        0.99641   [        -2.9051         5.7307 ]
#                          :      curvemin:      0.0075358         1.0067   [        -5.7307         3.5857 ]
#                          :     curvemean:      -0.014375        0.99615   [        -3.3701         5.7307 ]
#                          :     lambdamin:       0.022959         1.0117   [        -2.9579         5.7307 ]
#                          :    lambdamean:       0.020850         1.0043   [        -3.0098         5.7307 ]
#                          :     curvesign:       0.020685        0.98152   [        -3.0186         5.7307 ]
#                          : ------------------------------------------------------------------------------------
# Factory                  : Evaluate classifier: PyKeras
#                          :
# TFHandler_PyKeras        :      Variable             Mean             RMS     [        Min             Max ]
#                          : ------------------------------------------------------------------------------------
#                          :         nhits:      -0.067373        0.98861   [        -2.0098         5.7307 ]
#                          :      residual:      0.0050044         1.0109   [        -4.3770         3.8136 ]
#                          :             r:      0.0048427         1.0168   [        -5.7307         5.7307 ]
#                          :     S0rawPerp:      -0.020035         1.0023   [        -5.7307         3.6124 ]
#                          :    S0axisrawZ:       0.012440         1.0089   [        -2.9285         5.7307 ]
#                          : phi_S0axisraw:     -0.0034774        0.98613   [        -3.6364         3.4607 ]
#                          :           nCT:     -0.0031929         1.0006   [        -2.9311         3.6537 ]
#                          :           nGT:      -0.014713        0.98657   [        -3.2290         5.7307 ]
#                          :     tracksdca:      0.0055572        0.99641   [        -2.9051         5.7307 ]
#                          :      curvemin:      0.0075358         1.0067   [        -5.7307         3.5857 ]
#                          :     curvemean:      -0.014375        0.99615   [        -3.3701         5.7307 ]
#                          :     lambdamin:       0.022959         1.0117   [        -2.9579         5.7307 ]
#                          :    lambdamean:       0.020850         1.0043   [        -3.0098         5.7307 ]
#                          :     curvesign:       0.020685        0.98152   [        -3.0186         5.7307 ]
#                          : ------------------------------------------------------------------------------------
# PyKeras                  : [dataset] : Loop over test events and fill histograms with classifier response...
#                          :
# TFHandler_PyKeras        :      Variable             Mean             RMS     [        Min             Max ]
#                          : ------------------------------------------------------------------------------------
#                          :         nhits:      -0.067373        0.98861   [        -2.0098         5.7307 ]
#                          :      residual:      0.0050044         1.0109   [        -4.3770         3.8136 ]
#                          :             r:      0.0048427         1.0168   [        -5.7307         5.7307 ]
#                          :     S0rawPerp:      -0.020035         1.0023   [        -5.7307         3.6124 ]
#                          :    S0axisrawZ:       0.012440         1.0089   [        -2.9285         5.7307 ]
#                          : phi_S0axisraw:     -0.0034774        0.98613   [        -3.6364         3.4607 ]
#                          :           nCT:     -0.0031929         1.0006   [        -2.9311         3.6537 ]
#                          :           nGT:      -0.014713        0.98657   [        -3.2290         5.7307 ]
#                          :     tracksdca:      0.0055572        0.99641   [        -2.9051         5.7307 ]
#                          :      curvemin:      0.0075358         1.0067   [        -5.7307         3.5857 ]
#                          :     curvemean:      -0.014375        0.99615   [        -3.3701         5.7307 ]
#                          :     lambdamin:       0.022959         1.0117   [        -2.9579         5.7307 ]
#                          :    lambdamean:       0.020850         1.0043   [        -3.0098         5.7307 ]
#                          :     curvesign:       0.020685        0.98152   [        -3.0186         5.7307 ]
#                          : ------------------------------------------------------------------------------------
# Factory                  : Evaluate classifier: Cuts
#                          :
# <WARNING>                : You have asked for histogram MVA_EFF_BvsS which does not seem to exist in *Results* .. better don't use it
# <WARNING>                : You have asked for histogram EFF_BVSS_TR which does not seem to exist in *Results* .. better don't use it
# <WARNING>                :  unable to fill 96 efficiency bins
# TFHandler_Cuts           :      Variable             Mean             RMS     [        Min             Max ]
#                          : ------------------------------------------------------------------------------------
#                          :         nhits:         45.851         1362.0   [         3.0000         87200. ]
#                          :      residual:         2.0759         4.6489   [        -1.0000         47.539 ]
#                          :             r:         3.2423         3.3148   [         0.0000         40.814 ]
#                          :     S0rawPerp:        0.88455        0.13432   [        0.50008         1.0000 ]
#                          :    S0axisrawZ:        -7.0213         25.431   [        -99.000        0.99630 ]
#                          : phi_S0axisraw:         1.3951         1.0250   [     5.2742e-05         3.1416 ]
#                          :           nCT:         2.4369         1.6770   [         0.0000         15.000 ]
#                          :           nGT:         2.1231         1.5070   [         0.0000         15.000 ]
#                          :     tracksdca:        0.67748         1.3615   [         0.0000         14.720 ]
#                          :      curvemin:         709.93         2568.0   [     2.6632e-07         9999.0 ]
#                          :     curvemean:       0.010918       0.014319   [         0.0000        0.18366 ]
#                          :     lambdamin:         710.23         2567.9   [         0.0000         9999.0 ]
#                          :    lambdamean:        0.42949        0.32894   [         0.0000         2.7207 ]
#                          :     curvesign:       0.046125         1.3500   [        -7.0000         7.0000 ]
#                          : ------------------------------------------------------------------------------------
# Factory                  : Evaluate classifier: KNN
#                          :
# KNN                      : [dataset] : Loop over test events and fill histograms with classifier response...
#                          :
# TFHandler_KNN            :      Variable             Mean             RMS     [        Min             Max ]
#                          : ------------------------------------------------------------------------------------
#                          :         nhits:         45.851         1362.0   [         3.0000         87200. ]
#                          :      residual:         2.0759         4.6489   [        -1.0000         47.539 ]
#                          :             r:         3.2423         3.3148   [         0.0000         40.814 ]
#                          :     S0rawPerp:        0.88455        0.13432   [        0.50008         1.0000 ]
#                          :    S0axisrawZ:        -7.0213         25.431   [        -99.000        0.99630 ]
#                          : phi_S0axisraw:         1.3951         1.0250   [     5.2742e-05         3.1416 ]
#                          :           nCT:         2.4369         1.6770   [         0.0000         15.000 ]
#                          :           nGT:         2.1231         1.5070   [         0.0000         15.000 ]
#                          :     tracksdca:        0.67748         1.3615   [         0.0000         14.720 ]
#                          :      curvemin:         709.93         2568.0   [     2.6632e-07         9999.0 ]
#                          :     curvemean:       0.010918       0.014319   [         0.0000        0.18366 ]
#                          :     lambdamin:         710.23         2567.9   [         0.0000         9999.0 ]
#                          :    lambdamean:        0.42949        0.32894   [         0.0000         2.7207 ]
#                          :     curvesign:       0.046125         1.3500   [        -7.0000         7.0000 ]
#                          : ------------------------------------------------------------------------------------
# Factory                  : Evaluate classifier: SVM
#                          :
# TFHandler_SVM            :      Variable             Mean             RMS     [        Min             Max ]
#                          : ------------------------------------------------------------------------------------
#                          :         nhits:       -0.99911       0.028180   [        -1.0000        0.80416 ]
#                          :      residual:       -0.90482        0.14385   [        -1.0000        0.50197 ]
#                          :             r:       -0.85997        0.14316   [        -1.0000        0.76266 ]
#                          :     S0rawPerp:        0.52330        0.55461   [        -1.0642         1.0000 ]
#                          :    S0axisrawZ:        0.83959        0.50862   [        -1.0000        0.99995 ]
#                          : phi_S0axisraw:       -0.11192        0.65258   [        -1.0001         1.0000 ]
#                          :           nCT:       -0.65187        0.23957   [        -1.0000         1.1429 ]
#                          :           nGT:       -0.69670        0.21528   [        -1.0000         1.1429 ]
#                          :     tracksdca:       -0.91022        0.18041   [        -1.0000        0.95063 ]
#                          :      curvemin:       -0.85800        0.51365   [        -1.0000         1.0000 ]
#                          :     curvemean:       -0.87875        0.15901   [        -1.0000         1.0395 ]
#                          :     lambdamin:       -0.85794        0.51363   [        -1.0000         1.0000 ]
#                          :    lambdamean:       -0.60633        0.30151   [        -1.0000         1.4938 ]
#                          :     curvesign:      0.0057656        0.16875   [       -0.87500        0.87500 ]
#                          : ------------------------------------------------------------------------------------
# SVM                      : [dataset] : Loop over test events and fill histograms with classifier response...
#                          :
# TFHandler_SVM            :      Variable             Mean             RMS     [        Min             Max ]
#                          : ------------------------------------------------------------------------------------
#                          :         nhits:       -0.99911       0.028180   [        -1.0000        0.80416 ]
#                          :      residual:       -0.90482        0.14385   [        -1.0000        0.50197 ]
#                          :             r:       -0.85997        0.14316   [        -1.0000        0.76266 ]
#                          :     S0rawPerp:        0.52330        0.55461   [        -1.0642         1.0000 ]
#                          :    S0axisrawZ:        0.83959        0.50862   [        -1.0000        0.99995 ]
#                          : phi_S0axisraw:       -0.11192        0.65258   [        -1.0001         1.0000 ]
#                          :           nCT:       -0.65187        0.23957   [        -1.0000         1.1429 ]
#                          :           nGT:       -0.69670        0.21528   [        -1.0000         1.1429 ]
#                          :     tracksdca:       -0.91022        0.18041   [        -1.0000        0.95063 ]
#                          :      curvemin:       -0.85800        0.51365   [        -1.0000         1.0000 ]
#                          :     curvemean:       -0.87875        0.15901   [        -1.0000         1.0395 ]
#                          :     lambdamin:       -0.85794        0.51363   [        -1.0000         1.0000 ]
#                          :    lambdamean:       -0.60633        0.30151   [        -1.0000         1.4938 ]
#                          :     curvesign:      0.0057656        0.16875   [       -0.87500        0.87500 ]
#                          : ------------------------------------------------------------------------------------
# Factory                  : Evaluate classifier: BDT
#                          :
# BDT                      : [dataset] : Loop over test events and fill histograms with classifier response...
#                          :
# TFHandler_BDT            :      Variable             Mean             RMS     [        Min             Max ]
#                          : ------------------------------------------------------------------------------------
#                          :         nhits:         45.851         1362.0   [         3.0000         87200. ]
#                          :      residual:         2.0759         4.6489   [        -1.0000         47.539 ]
#                          :             r:         3.2423         3.3148   [         0.0000         40.814 ]
#                          :     S0rawPerp:        0.88455        0.13432   [        0.50008         1.0000 ]
#                          :    S0axisrawZ:        -7.0213         25.431   [        -99.000        0.99630 ]
#                          : phi_S0axisraw:         1.3951         1.0250   [     5.2742e-05         3.1416 ]
#                          :           nCT:         2.4369         1.6770   [         0.0000         15.000 ]
#                          :           nGT:         2.1231         1.5070   [         0.0000         15.000 ]
#                          :     tracksdca:        0.67748         1.3615   [         0.0000         14.720 ]
#                          :      curvemin:         709.93         2568.0   [     2.6632e-07         9999.0 ]
#                          :     curvemean:       0.010918       0.014319   [         0.0000        0.18366 ]
#                          :     lambdamin:         710.23         2567.9   [         0.0000         9999.0 ]
#                          :    lambdamean:        0.42949        0.32894   [         0.0000         2.7207 ]
#                          :     curvesign:       0.046125         1.3500   [        -7.0000         7.0000 ]
#                          : ------------------------------------------------------------------------------------
# Factory                  : Evaluate classifier: BDTB
#                          :
# BDTB                     : [dataset] : Loop over test events and fill histograms with classifier response...
#                          :
#                          : Also filling probability and rarity histograms (on request)...
# TFHandler_BDTB           :      Variable             Mean             RMS     [        Min             Max ]
#                          : ------------------------------------------------------------------------------------
#                          :         nhits:         45.851         1362.0   [         3.0000         87200. ]
#                          :      residual:         2.0759         4.6489   [        -1.0000         47.539 ]
#                          :             r:         3.2423         3.3148   [         0.0000         40.814 ]
#                          :     S0rawPerp:        0.88455        0.13432   [        0.50008         1.0000 ]
#                          :    S0axisrawZ:        -7.0213         25.431   [        -99.000        0.99630 ]
#                          : phi_S0axisraw:         1.3951         1.0250   [     5.2742e-05         3.1416 ]
#                          :           nCT:         2.4369         1.6770   [         0.0000         15.000 ]
#                          :           nGT:         2.1231         1.5070   [         0.0000         15.000 ]
#                          :     tracksdca:        0.67748         1.3615   [         0.0000         14.720 ]
#                          :      curvemin:         709.93         2568.0   [     2.6632e-07         9999.0 ]
#                          :     curvemean:       0.010918       0.014319   [         0.0000        0.18366 ]
#                          :     lambdamin:         710.23         2567.9   [         0.0000         9999.0 ]
#                          :    lambdamean:        0.42949        0.32894   [         0.0000         2.7207 ]
#                          :     curvesign:       0.046125         1.3500   [        -7.0000         7.0000 ]
#                          : ------------------------------------------------------------------------------------
# Factory                  : Evaluate classifier: BDTG
#                          :
# BDTG                     : [dataset] : Loop over test events and fill histograms with classifier response...
#                          :
# TFHandler_BDTG           :      Variable             Mean             RMS     [        Min             Max ]
#                          : ------------------------------------------------------------------------------------
#                          :         nhits:         45.851         1362.0   [         3.0000         87200. ]
#                          :      residual:         2.0759         4.6489   [        -1.0000         47.539 ]
#                          :             r:         3.2423         3.3148   [         0.0000         40.814 ]
#                          :     S0rawPerp:        0.88455        0.13432   [        0.50008         1.0000 ]
#                          :    S0axisrawZ:        -7.0213         25.431   [        -99.000        0.99630 ]
#                          : phi_S0axisraw:         1.3951         1.0250   [     5.2742e-05         3.1416 ]
#                          :           nCT:         2.4369         1.6770   [         0.0000         15.000 ]
#                          :           nGT:         2.1231         1.5070   [         0.0000         15.000 ]
#                          :     tracksdca:        0.67748         1.3615   [         0.0000         14.720 ]
#                          :      curvemin:         709.93         2568.0   [     2.6632e-07         9999.0 ]
#                          :     curvemean:       0.010918       0.014319   [         0.0000        0.18366 ]
#                          :     lambdamin:         710.23         2567.9   [         0.0000         9999.0 ]
#                          :    lambdamean:        0.42949        0.32894   [         0.0000         2.7207 ]
#                          :     curvesign:       0.046125         1.3500   [        -7.0000         7.0000 ]
#                          : ------------------------------------------------------------------------------------
#                          :
#                          : Evaluation results ranked by best signal efficiency and purity (area)
#                          : -------------------------------------------------------------------------------------------------------------------
#                          : DataSet       MVA
#                          : Name:         Method:          ROC-integ
#                          : dataset       BDT            : 0.980
#                          : dataset       BDTB           : 0.980
#                          : dataset       BDTG           : 0.980
#                          : dataset       PyKeras        : 0.974
#                          : dataset       KNN            : 0.968
#                          : dataset       SVM            : 0.965
#                          : dataset       Fisher         : 0.951
#                          : dataset       Cuts           : 0.500
#                          : -------------------------------------------------------------------------------------------------------------------
#                          :
#                          : Testing efficiency compared to training efficiency (overtraining check)
#                          : -------------------------------------------------------------------------------------------------------------------
#                          : DataSet              MVA              Signal efficiency: from test sample (from training sample)
#                          : Name:                Method:          @B=0.01             @B=0.10            @B=0.30
#                          : -------------------------------------------------------------------------------------------------------------------
#                          : dataset              BDT            : 0.792 (0.838)       0.937 (0.947)      0.987 (0.989)
#                          : dataset              BDTB           : 0.793 (0.852)       0.937 (0.948)      0.988 (0.989)
#                          : dataset              BDTG           : 0.792 (0.838)       0.939 (0.949)      0.987 (0.988)
#                          : dataset              PyKeras        : 0.768 (0.779)       0.919 (0.931)      0.981 (0.982)
#                          : dataset              KNN            : 0.739 (0.781)       0.914 (0.927)      0.976 (0.979)
#                          : dataset              SVM            : 0.732 (0.761)       0.897 (0.899)      0.966 (0.967)
#                          : dataset              Fisher         : 0.557 (0.591)       0.890 (0.897)      0.948 (0.948)
#                          : dataset              Cuts           : 0.010 (1.000)       0.100 (1.000)      0.300 (1.000)
#                          : -------------------------------------------------------------------------------------------------------------------
#                          :
# Dataset:dataset          : Created tree 'TestTree' with 8000 events
#                          :
# Dataset:dataset          : Created tree 'TrainTree' with 12000 events
#                          :
# Factory                  : Thank you for using TMVA!
#                          : For citation information, please visit: http://tmva.sf.net/citeTMVA.html

# %%
# The TMVA.root file has lots of nice diagnostic plots inside it now:
output.ls()

# TMVA::Gui() in the root program doesn't have a batch mode yet (so I don't believe it can be used from jupyter)
# Out:
# TFile**		TMVA.root
#  TFile*		TMVA.root
#   TDirectoryFile*		dataset	dataset
#    TDirectoryFile*		InputVariables_Deco_Gauss	InputVariables_Deco_Gauss
#     TDirectoryFile*		CorrelationPlots	CorrelationPlots
#      KEY: TH2F	scat_residual_vs_nhits_Signal_Deco_Gauss;1	residual versus nhits (Signal)_Deco_Gauss
#      KEY: TProfile	prof_residual_vs_nhits_Signal_Deco_Gauss;1	profile residual versus nhits (Signal)_Deco_Gauss
#      KEY: TH2F	scat_residual_vs_nhits_Background_Deco_Gauss;1	residual versus nhits (Background)_Deco_Gauss
#      KEY: TProfile	prof_residual_vs_nhits_Background_Deco_Gauss;1	profile residual versus nhits (Background)_Deco_Gauss
#      KEY: TH2F	scat_r_vs_nhits_Signal_Deco_Gauss;1	r versus nhits (Signal)_Deco_Gauss
#      KEY: TProfile	prof_r_vs_nhits_Signal_Deco_Gauss;1	profile r versus nhits (Signal)_Deco_Gauss
#      KEY: TH2F	scat_r_vs_nhits_Background_Deco_Gauss;1	r versus nhits (Background)_Deco_Gauss
#      KEY: TProfile	prof_r_vs_nhits_Background_Deco_Gauss;1	profile r versus nhits (Background)_Deco_Gauss
#      KEY: TH2F	scat_S0rawPerp_vs_nhits_Signal_Deco_Gauss;1	S0rawPerp versus nhits (Signal)_Deco_Gauss
#      KEY: TProfile	prof_S0rawPerp_vs_nhits_Signal_Deco_Gauss;1	profile S0rawPerp versus nhits (Signal)_Deco_Gauss
#      KEY: TH2F	scat_S0rawPerp_vs_nhits_Background_Deco_Gauss;1	S0rawPerp versus nhits (Background)_Deco_Gauss
#      KEY: TProfile	prof_S0rawPerp_vs_nhits_Background_Deco_Gauss;1	profile S0rawPerp versus nhits (Background)_Deco_Gauss
#      KEY: TH2F	scat_S0axisrawZ_vs_nhits_Signal_Deco_Gauss;1	S0axisrawZ versus nhits (Signal)_Deco_Gauss
#      KEY: TProfile	prof_S0axisrawZ_vs_nhits_Signal_Deco_Gauss;1	profile S0axisrawZ versus nhits (Signal)_Deco_Gauss
#      KEY: TH2F	scat_S0axisrawZ_vs_nhits_Background_Deco_Gauss;1	S0axisrawZ versus nhits (Background)_Deco_Gauss
#      KEY: TProfile	prof_S0axisrawZ_vs_nhits_Background_Deco_Gauss;1	profile S0axisrawZ versus nhits (Background)_Deco_Gauss
#      KEY: TH2F	scat_phi_S0axisraw_vs_nhits_Signal_Deco_Gauss;1	phi_S0axisraw versus nhits (Signal)_Deco_Gauss
#      KEY: TProfile	prof_phi_S0axisraw_vs_nhits_Signal_Deco_Gauss;1	profile phi_S0axisraw versus nhits (Signal)_Deco_Gauss
#      KEY: TH2F	scat_phi_S0axisraw_vs_nhits_Background_Deco_Gauss;1	phi_S0axisraw versus nhits (Background)_Deco_Gauss
#      KEY: TProfile	prof_phi_S0axisraw_vs_nhits_Background_Deco_Gauss;1	profile phi_S0axisraw versus nhits (Background)_Deco_Gauss
#      KEY: TH2F	scat_nCT_vs_nhits_Signal_Deco_Gauss;1	nCT versus nhits (Signal)_Deco_Gauss
#      KEY: TProfile	prof_nCT_vs_nhits_Signal_Deco_Gauss;1	profile nCT versus nhits (Signal)_Deco_Gauss
#      KEY: TH2F	scat_nCT_vs_nhits_Background_Deco_Gauss;1	nCT versus nhits (Background)_Deco_Gauss
#      KEY: TProfile	prof_nCT_vs_nhits_Background_Deco_Gauss;1	profile nCT versus nhits (Background)_Deco_Gauss
#      KEY: TH2F	scat_nGT_vs_nhits_Signal_Deco_Gauss;1	nGT versus nhits (Signal)_Deco_Gauss
#      KEY: TProfile	prof_nGT_vs_nhits_Signal_Deco_Gauss;1	profile nGT versus nhits (Signal)_Deco_Gauss
#      KEY: TH2F	scat_nGT_vs_nhits_Background_Deco_Gauss;1	nGT versus nhits (Background)_Deco_Gauss
#      KEY: TProfile	prof_nGT_vs_nhits_Background_Deco_Gauss;1	profile nGT versus nhits (Background)_Deco_Gauss
#      KEY: TH2F	scat_tracksdca_vs_nhits_Signal_Deco_Gauss;1	tracksdca versus nhits (Signal)_Deco_Gauss
#      KEY: TProfile	prof_tracksdca_vs_nhits_Signal_Deco_Gauss;1	profile tracksdca versus nhits (Signal)_Deco_Gauss
#      KEY: TH2F	scat_tracksdca_vs_nhits_Background_Deco_Gauss;1	tracksdca versus nhits (Background)_Deco_Gauss
#      KEY: TProfile	prof_tracksdca_vs_nhits_Background_Deco_Gauss;1	profile tracksdca versus nhits (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvemin_vs_nhits_Signal_Deco_Gauss;1	curvemin versus nhits (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvemin_vs_nhits_Signal_Deco_Gauss;1	profile curvemin versus nhits (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvemin_vs_nhits_Background_Deco_Gauss;1	curvemin versus nhits (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvemin_vs_nhits_Background_Deco_Gauss;1	profile curvemin versus nhits (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvemean_vs_nhits_Signal_Deco_Gauss;1	curvemean versus nhits (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvemean_vs_nhits_Signal_Deco_Gauss;1	profile curvemean versus nhits (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvemean_vs_nhits_Background_Deco_Gauss;1	curvemean versus nhits (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvemean_vs_nhits_Background_Deco_Gauss;1	profile curvemean versus nhits (Background)_Deco_Gauss
#      KEY: TH2F	scat_lambdamin_vs_nhits_Signal_Deco_Gauss;1	lambdamin versus nhits (Signal)_Deco_Gauss
#      KEY: TProfile	prof_lambdamin_vs_nhits_Signal_Deco_Gauss;1	profile lambdamin versus nhits (Signal)_Deco_Gauss
#      KEY: TH2F	scat_lambdamin_vs_nhits_Background_Deco_Gauss;1	lambdamin versus nhits (Background)_Deco_Gauss
#      KEY: TProfile	prof_lambdamin_vs_nhits_Background_Deco_Gauss;1	profile lambdamin versus nhits (Background)_Deco_Gauss
#      KEY: TH2F	scat_lambdamean_vs_nhits_Signal_Deco_Gauss;1	lambdamean versus nhits (Signal)_Deco_Gauss
#      KEY: TProfile	prof_lambdamean_vs_nhits_Signal_Deco_Gauss;1	profile lambdamean versus nhits (Signal)_Deco_Gauss
#      KEY: TH2F	scat_lambdamean_vs_nhits_Background_Deco_Gauss;1	lambdamean versus nhits (Background)_Deco_Gauss
#      KEY: TProfile	prof_lambdamean_vs_nhits_Background_Deco_Gauss;1	profile lambdamean versus nhits (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvesign_vs_nhits_Signal_Deco_Gauss;1	curvesign versus nhits (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvesign_vs_nhits_Signal_Deco_Gauss;1	profile curvesign versus nhits (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvesign_vs_nhits_Background_Deco_Gauss;1	curvesign versus nhits (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvesign_vs_nhits_Background_Deco_Gauss;1	profile curvesign versus nhits (Background)_Deco_Gauss
#      KEY: TH2F	scat_r_vs_residual_Signal_Deco_Gauss;1	r versus residual (Signal)_Deco_Gauss
#      KEY: TProfile	prof_r_vs_residual_Signal_Deco_Gauss;1	profile r versus residual (Signal)_Deco_Gauss
#      KEY: TH2F	scat_r_vs_residual_Background_Deco_Gauss;1	r versus residual (Background)_Deco_Gauss
#      KEY: TProfile	prof_r_vs_residual_Background_Deco_Gauss;1	profile r versus residual (Background)_Deco_Gauss
#      KEY: TH2F	scat_S0rawPerp_vs_residual_Signal_Deco_Gauss;1	S0rawPerp versus residual (Signal)_Deco_Gauss
#      KEY: TProfile	prof_S0rawPerp_vs_residual_Signal_Deco_Gauss;1	profile S0rawPerp versus residual (Signal)_Deco_Gauss
#      KEY: TH2F	scat_S0rawPerp_vs_residual_Background_Deco_Gauss;1	S0rawPerp versus residual (Background)_Deco_Gauss
#      KEY: TProfile	prof_S0rawPerp_vs_residual_Background_Deco_Gauss;1	profile S0rawPerp versus residual (Background)_Deco_Gauss
#      KEY: TH2F	scat_S0axisrawZ_vs_residual_Signal_Deco_Gauss;1	S0axisrawZ versus residual (Signal)_Deco_Gauss
#      KEY: TProfile	prof_S0axisrawZ_vs_residual_Signal_Deco_Gauss;1	profile S0axisrawZ versus residual (Signal)_Deco_Gauss
#      KEY: TH2F	scat_S0axisrawZ_vs_residual_Background_Deco_Gauss;1	S0axisrawZ versus residual (Background)_Deco_Gauss
#      KEY: TProfile	prof_S0axisrawZ_vs_residual_Background_Deco_Gauss;1	profile S0axisrawZ versus residual (Background)_Deco_Gauss
#      KEY: TH2F	scat_phi_S0axisraw_vs_residual_Signal_Deco_Gauss;1	phi_S0axisraw versus residual (Signal)_Deco_Gauss
#      KEY: TProfile	prof_phi_S0axisraw_vs_residual_Signal_Deco_Gauss;1	profile phi_S0axisraw versus residual (Signal)_Deco_Gauss
#      KEY: TH2F	scat_phi_S0axisraw_vs_residual_Background_Deco_Gauss;1	phi_S0axisraw versus residual (Background)_Deco_Gauss
#      KEY: TProfile	prof_phi_S0axisraw_vs_residual_Background_Deco_Gauss;1	profile phi_S0axisraw versus residual (Background)_Deco_Gauss
#      KEY: TH2F	scat_nCT_vs_residual_Signal_Deco_Gauss;1	nCT versus residual (Signal)_Deco_Gauss
#      KEY: TProfile	prof_nCT_vs_residual_Signal_Deco_Gauss;1	profile nCT versus residual (Signal)_Deco_Gauss
#      KEY: TH2F	scat_nCT_vs_residual_Background_Deco_Gauss;1	nCT versus residual (Background)_Deco_Gauss
#      KEY: TProfile	prof_nCT_vs_residual_Background_Deco_Gauss;1	profile nCT versus residual (Background)_Deco_Gauss
#      KEY: TH2F	scat_nGT_vs_residual_Signal_Deco_Gauss;1	nGT versus residual (Signal)_Deco_Gauss
#      KEY: TProfile	prof_nGT_vs_residual_Signal_Deco_Gauss;1	profile nGT versus residual (Signal)_Deco_Gauss
#      KEY: TH2F	scat_nGT_vs_residual_Background_Deco_Gauss;1	nGT versus residual (Background)_Deco_Gauss
#      KEY: TProfile	prof_nGT_vs_residual_Background_Deco_Gauss;1	profile nGT versus residual (Background)_Deco_Gauss
#      KEY: TH2F	scat_tracksdca_vs_residual_Signal_Deco_Gauss;1	tracksdca versus residual (Signal)_Deco_Gauss
#      KEY: TProfile	prof_tracksdca_vs_residual_Signal_Deco_Gauss;1	profile tracksdca versus residual (Signal)_Deco_Gauss
#      KEY: TH2F	scat_tracksdca_vs_residual_Background_Deco_Gauss;1	tracksdca versus residual (Background)_Deco_Gauss
#      KEY: TProfile	prof_tracksdca_vs_residual_Background_Deco_Gauss;1	profile tracksdca versus residual (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvemin_vs_residual_Signal_Deco_Gauss;1	curvemin versus residual (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvemin_vs_residual_Signal_Deco_Gauss;1	profile curvemin versus residual (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvemin_vs_residual_Background_Deco_Gauss;1	curvemin versus residual (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvemin_vs_residual_Background_Deco_Gauss;1	profile curvemin versus residual (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvemean_vs_residual_Signal_Deco_Gauss;1	curvemean versus residual (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvemean_vs_residual_Signal_Deco_Gauss;1	profile curvemean versus residual (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvemean_vs_residual_Background_Deco_Gauss;1	curvemean versus residual (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvemean_vs_residual_Background_Deco_Gauss;1	profile curvemean versus residual (Background)_Deco_Gauss
#      KEY: TH2F	scat_lambdamin_vs_residual_Signal_Deco_Gauss;1	lambdamin versus residual (Signal)_Deco_Gauss
#      KEY: TProfile	prof_lambdamin_vs_residual_Signal_Deco_Gauss;1	profile lambdamin versus residual (Signal)_Deco_Gauss
#      KEY: TH2F	scat_lambdamin_vs_residual_Background_Deco_Gauss;1	lambdamin versus residual (Background)_Deco_Gauss
#      KEY: TProfile	prof_lambdamin_vs_residual_Background_Deco_Gauss;1	profile lambdamin versus residual (Background)_Deco_Gauss
#      KEY: TH2F	scat_lambdamean_vs_residual_Signal_Deco_Gauss;1	lambdamean versus residual (Signal)_Deco_Gauss
#      KEY: TProfile	prof_lambdamean_vs_residual_Signal_Deco_Gauss;1	profile lambdamean versus residual (Signal)_Deco_Gauss
#      KEY: TH2F	scat_lambdamean_vs_residual_Background_Deco_Gauss;1	lambdamean versus residual (Background)_Deco_Gauss
#      KEY: TProfile	prof_lambdamean_vs_residual_Background_Deco_Gauss;1	profile lambdamean versus residual (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvesign_vs_residual_Signal_Deco_Gauss;1	curvesign versus residual (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvesign_vs_residual_Signal_Deco_Gauss;1	profile curvesign versus residual (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvesign_vs_residual_Background_Deco_Gauss;1	curvesign versus residual (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvesign_vs_residual_Background_Deco_Gauss;1	profile curvesign versus residual (Background)_Deco_Gauss
#      KEY: TH2F	scat_S0rawPerp_vs_r_Signal_Deco_Gauss;1	S0rawPerp versus r (Signal)_Deco_Gauss
#      KEY: TProfile	prof_S0rawPerp_vs_r_Signal_Deco_Gauss;1	profile S0rawPerp versus r (Signal)_Deco_Gauss
#      KEY: TH2F	scat_S0rawPerp_vs_r_Background_Deco_Gauss;1	S0rawPerp versus r (Background)_Deco_Gauss
#      KEY: TProfile	prof_S0rawPerp_vs_r_Background_Deco_Gauss;1	profile S0rawPerp versus r (Background)_Deco_Gauss
#      KEY: TH2F	scat_S0axisrawZ_vs_r_Signal_Deco_Gauss;1	S0axisrawZ versus r (Signal)_Deco_Gauss
#      KEY: TProfile	prof_S0axisrawZ_vs_r_Signal_Deco_Gauss;1	profile S0axisrawZ versus r (Signal)_Deco_Gauss
#      KEY: TH2F	scat_S0axisrawZ_vs_r_Background_Deco_Gauss;1	S0axisrawZ versus r (Background)_Deco_Gauss
#      KEY: TProfile	prof_S0axisrawZ_vs_r_Background_Deco_Gauss;1	profile S0axisrawZ versus r (Background)_Deco_Gauss
#      KEY: TH2F	scat_phi_S0axisraw_vs_r_Signal_Deco_Gauss;1	phi_S0axisraw versus r (Signal)_Deco_Gauss
#      KEY: TProfile	prof_phi_S0axisraw_vs_r_Signal_Deco_Gauss;1	profile phi_S0axisraw versus r (Signal)_Deco_Gauss
#      KEY: TH2F	scat_phi_S0axisraw_vs_r_Background_Deco_Gauss;1	phi_S0axisraw versus r (Background)_Deco_Gauss
#      KEY: TProfile	prof_phi_S0axisraw_vs_r_Background_Deco_Gauss;1	profile phi_S0axisraw versus r (Background)_Deco_Gauss
#      KEY: TH2F	scat_nCT_vs_r_Signal_Deco_Gauss;1	nCT versus r (Signal)_Deco_Gauss
#      KEY: TProfile	prof_nCT_vs_r_Signal_Deco_Gauss;1	profile nCT versus r (Signal)_Deco_Gauss
#      KEY: TH2F	scat_nCT_vs_r_Background_Deco_Gauss;1	nCT versus r (Background)_Deco_Gauss
#      KEY: TProfile	prof_nCT_vs_r_Background_Deco_Gauss;1	profile nCT versus r (Background)_Deco_Gauss
#      KEY: TH2F	scat_nGT_vs_r_Signal_Deco_Gauss;1	nGT versus r (Signal)_Deco_Gauss
#      KEY: TProfile	prof_nGT_vs_r_Signal_Deco_Gauss;1	profile nGT versus r (Signal)_Deco_Gauss
#      KEY: TH2F	scat_nGT_vs_r_Background_Deco_Gauss;1	nGT versus r (Background)_Deco_Gauss
#      KEY: TProfile	prof_nGT_vs_r_Background_Deco_Gauss;1	profile nGT versus r (Background)_Deco_Gauss
#      KEY: TH2F	scat_tracksdca_vs_r_Signal_Deco_Gauss;1	tracksdca versus r (Signal)_Deco_Gauss
#      KEY: TProfile	prof_tracksdca_vs_r_Signal_Deco_Gauss;1	profile tracksdca versus r (Signal)_Deco_Gauss
#      KEY: TH2F	scat_tracksdca_vs_r_Background_Deco_Gauss;1	tracksdca versus r (Background)_Deco_Gauss
#      KEY: TProfile	prof_tracksdca_vs_r_Background_Deco_Gauss;1	profile tracksdca versus r (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvemin_vs_r_Signal_Deco_Gauss;1	curvemin versus r (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvemin_vs_r_Signal_Deco_Gauss;1	profile curvemin versus r (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvemin_vs_r_Background_Deco_Gauss;1	curvemin versus r (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvemin_vs_r_Background_Deco_Gauss;1	profile curvemin versus r (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvemean_vs_r_Signal_Deco_Gauss;1	curvemean versus r (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvemean_vs_r_Signal_Deco_Gauss;1	profile curvemean versus r (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvemean_vs_r_Background_Deco_Gauss;1	curvemean versus r (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvemean_vs_r_Background_Deco_Gauss;1	profile curvemean versus r (Background)_Deco_Gauss
#      KEY: TH2F	scat_lambdamin_vs_r_Signal_Deco_Gauss;1	lambdamin versus r (Signal)_Deco_Gauss
#      KEY: TProfile	prof_lambdamin_vs_r_Signal_Deco_Gauss;1	profile lambdamin versus r (Signal)_Deco_Gauss
#      KEY: TH2F	scat_lambdamin_vs_r_Background_Deco_Gauss;1	lambdamin versus r (Background)_Deco_Gauss
#      KEY: TProfile	prof_lambdamin_vs_r_Background_Deco_Gauss;1	profile lambdamin versus r (Background)_Deco_Gauss
#      KEY: TH2F	scat_lambdamean_vs_r_Signal_Deco_Gauss;1	lambdamean versus r (Signal)_Deco_Gauss
#      KEY: TProfile	prof_lambdamean_vs_r_Signal_Deco_Gauss;1	profile lambdamean versus r (Signal)_Deco_Gauss
#      KEY: TH2F	scat_lambdamean_vs_r_Background_Deco_Gauss;1	lambdamean versus r (Background)_Deco_Gauss
#      KEY: TProfile	prof_lambdamean_vs_r_Background_Deco_Gauss;1	profile lambdamean versus r (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvesign_vs_r_Signal_Deco_Gauss;1	curvesign versus r (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvesign_vs_r_Signal_Deco_Gauss;1	profile curvesign versus r (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvesign_vs_r_Background_Deco_Gauss;1	curvesign versus r (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvesign_vs_r_Background_Deco_Gauss;1	profile curvesign versus r (Background)_Deco_Gauss
#      KEY: TH2F	scat_S0axisrawZ_vs_S0rawPerp_Signal_Deco_Gauss;1	S0axisrawZ versus S0rawPerp (Signal)_Deco_Gauss
#      KEY: TProfile	prof_S0axisrawZ_vs_S0rawPerp_Signal_Deco_Gauss;1	profile S0axisrawZ versus S0rawPerp (Signal)_Deco_Gauss
#      KEY: TH2F	scat_S0axisrawZ_vs_S0rawPerp_Background_Deco_Gauss;1	S0axisrawZ versus S0rawPerp (Background)_Deco_Gauss
#      KEY: TProfile	prof_S0axisrawZ_vs_S0rawPerp_Background_Deco_Gauss;1	profile S0axisrawZ versus S0rawPerp (Background)_Deco_Gauss
#      KEY: TH2F	scat_phi_S0axisraw_vs_S0rawPerp_Signal_Deco_Gauss;1	phi_S0axisraw versus S0rawPerp (Signal)_Deco_Gauss
#      KEY: TProfile	prof_phi_S0axisraw_vs_S0rawPerp_Signal_Deco_Gauss;1	profile phi_S0axisraw versus S0rawPerp (Signal)_Deco_Gauss
#      KEY: TH2F	scat_phi_S0axisraw_vs_S0rawPerp_Background_Deco_Gauss;1	phi_S0axisraw versus S0rawPerp (Background)_Deco_Gauss
#      KEY: TProfile	prof_phi_S0axisraw_vs_S0rawPerp_Background_Deco_Gauss;1	profile phi_S0axisraw versus S0rawPerp (Background)_Deco_Gauss
#      KEY: TH2F	scat_nCT_vs_S0rawPerp_Signal_Deco_Gauss;1	nCT versus S0rawPerp (Signal)_Deco_Gauss
#      KEY: TProfile	prof_nCT_vs_S0rawPerp_Signal_Deco_Gauss;1	profile nCT versus S0rawPerp (Signal)_Deco_Gauss
#      KEY: TH2F	scat_nCT_vs_S0rawPerp_Background_Deco_Gauss;1	nCT versus S0rawPerp (Background)_Deco_Gauss
#      KEY: TProfile	prof_nCT_vs_S0rawPerp_Background_Deco_Gauss;1	profile nCT versus S0rawPerp (Background)_Deco_Gauss
#      KEY: TH2F	scat_nGT_vs_S0rawPerp_Signal_Deco_Gauss;1	nGT versus S0rawPerp (Signal)_Deco_Gauss
#      KEY: TProfile	prof_nGT_vs_S0rawPerp_Signal_Deco_Gauss;1	profile nGT versus S0rawPerp (Signal)_Deco_Gauss
#      KEY: TH2F	scat_nGT_vs_S0rawPerp_Background_Deco_Gauss;1	nGT versus S0rawPerp (Background)_Deco_Gauss
#      KEY: TProfile	prof_nGT_vs_S0rawPerp_Background_Deco_Gauss;1	profile nGT versus S0rawPerp (Background)_Deco_Gauss
#      KEY: TH2F	scat_tracksdca_vs_S0rawPerp_Signal_Deco_Gauss;1	tracksdca versus S0rawPerp (Signal)_Deco_Gauss
#      KEY: TProfile	prof_tracksdca_vs_S0rawPerp_Signal_Deco_Gauss;1	profile tracksdca versus S0rawPerp (Signal)_Deco_Gauss
#      KEY: TH2F	scat_tracksdca_vs_S0rawPerp_Background_Deco_Gauss;1	tracksdca versus S0rawPerp (Background)_Deco_Gauss
#      KEY: TProfile	prof_tracksdca_vs_S0rawPerp_Background_Deco_Gauss;1	profile tracksdca versus S0rawPerp (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvemin_vs_S0rawPerp_Signal_Deco_Gauss;1	curvemin versus S0rawPerp (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvemin_vs_S0rawPerp_Signal_Deco_Gauss;1	profile curvemin versus S0rawPerp (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvemin_vs_S0rawPerp_Background_Deco_Gauss;1	curvemin versus S0rawPerp (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvemin_vs_S0rawPerp_Background_Deco_Gauss;1	profile curvemin versus S0rawPerp (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvemean_vs_S0rawPerp_Signal_Deco_Gauss;1	curvemean versus S0rawPerp (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvemean_vs_S0rawPerp_Signal_Deco_Gauss;1	profile curvemean versus S0rawPerp (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvemean_vs_S0rawPerp_Background_Deco_Gauss;1	curvemean versus S0rawPerp (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvemean_vs_S0rawPerp_Background_Deco_Gauss;1	profile curvemean versus S0rawPerp (Background)_Deco_Gauss
#      KEY: TH2F	scat_lambdamin_vs_S0rawPerp_Signal_Deco_Gauss;1	lambdamin versus S0rawPerp (Signal)_Deco_Gauss
#      KEY: TProfile	prof_lambdamin_vs_S0rawPerp_Signal_Deco_Gauss;1	profile lambdamin versus S0rawPerp (Signal)_Deco_Gauss
#      KEY: TH2F	scat_lambdamin_vs_S0rawPerp_Background_Deco_Gauss;1	lambdamin versus S0rawPerp (Background)_Deco_Gauss
#      KEY: TProfile	prof_lambdamin_vs_S0rawPerp_Background_Deco_Gauss;1	profile lambdamin versus S0rawPerp (Background)_Deco_Gauss
#      KEY: TH2F	scat_lambdamean_vs_S0rawPerp_Signal_Deco_Gauss;1	lambdamean versus S0rawPerp (Signal)_Deco_Gauss
#      KEY: TProfile	prof_lambdamean_vs_S0rawPerp_Signal_Deco_Gauss;1	profile lambdamean versus S0rawPerp (Signal)_Deco_Gauss
#      KEY: TH2F	scat_lambdamean_vs_S0rawPerp_Background_Deco_Gauss;1	lambdamean versus S0rawPerp (Background)_Deco_Gauss
#      KEY: TProfile	prof_lambdamean_vs_S0rawPerp_Background_Deco_Gauss;1	profile lambdamean versus S0rawPerp (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvesign_vs_S0rawPerp_Signal_Deco_Gauss;1	curvesign versus S0rawPerp (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvesign_vs_S0rawPerp_Signal_Deco_Gauss;1	profile curvesign versus S0rawPerp (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvesign_vs_S0rawPerp_Background_Deco_Gauss;1	curvesign versus S0rawPerp (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvesign_vs_S0rawPerp_Background_Deco_Gauss;1	profile curvesign versus S0rawPerp (Background)_Deco_Gauss
#      KEY: TH2F	scat_phi_S0axisraw_vs_S0axisrawZ_Signal_Deco_Gauss;1	phi_S0axisraw versus S0axisrawZ (Signal)_Deco_Gauss
#      KEY: TProfile	prof_phi_S0axisraw_vs_S0axisrawZ_Signal_Deco_Gauss;1	profile phi_S0axisraw versus S0axisrawZ (Signal)_Deco_Gauss
#      KEY: TH2F	scat_phi_S0axisraw_vs_S0axisrawZ_Background_Deco_Gauss;1	phi_S0axisraw versus S0axisrawZ (Background)_Deco_Gauss
#      KEY: TProfile	prof_phi_S0axisraw_vs_S0axisrawZ_Background_Deco_Gauss;1	profile phi_S0axisraw versus S0axisrawZ (Background)_Deco_Gauss
#      KEY: TH2F	scat_nCT_vs_S0axisrawZ_Signal_Deco_Gauss;1	nCT versus S0axisrawZ (Signal)_Deco_Gauss
#      KEY: TProfile	prof_nCT_vs_S0axisrawZ_Signal_Deco_Gauss;1	profile nCT versus S0axisrawZ (Signal)_Deco_Gauss
#      KEY: TH2F	scat_nCT_vs_S0axisrawZ_Background_Deco_Gauss;1	nCT versus S0axisrawZ (Background)_Deco_Gauss
#      KEY: TProfile	prof_nCT_vs_S0axisrawZ_Background_Deco_Gauss;1	profile nCT versus S0axisrawZ (Background)_Deco_Gauss
#      KEY: TH2F	scat_nGT_vs_S0axisrawZ_Signal_Deco_Gauss;1	nGT versus S0axisrawZ (Signal)_Deco_Gauss
#      KEY: TProfile	prof_nGT_vs_S0axisrawZ_Signal_Deco_Gauss;1	profile nGT versus S0axisrawZ (Signal)_Deco_Gauss
#      KEY: TH2F	scat_nGT_vs_S0axisrawZ_Background_Deco_Gauss;1	nGT versus S0axisrawZ (Background)_Deco_Gauss
#      KEY: TProfile	prof_nGT_vs_S0axisrawZ_Background_Deco_Gauss;1	profile nGT versus S0axisrawZ (Background)_Deco_Gauss
#      KEY: TH2F	scat_tracksdca_vs_S0axisrawZ_Signal_Deco_Gauss;1	tracksdca versus S0axisrawZ (Signal)_Deco_Gauss
#      KEY: TProfile	prof_tracksdca_vs_S0axisrawZ_Signal_Deco_Gauss;1	profile tracksdca versus S0axisrawZ (Signal)_Deco_Gauss
#      KEY: TH2F	scat_tracksdca_vs_S0axisrawZ_Background_Deco_Gauss;1	tracksdca versus S0axisrawZ (Background)_Deco_Gauss
#      KEY: TProfile	prof_tracksdca_vs_S0axisrawZ_Background_Deco_Gauss;1	profile tracksdca versus S0axisrawZ (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvemin_vs_S0axisrawZ_Signal_Deco_Gauss;1	curvemin versus S0axisrawZ (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvemin_vs_S0axisrawZ_Signal_Deco_Gauss;1	profile curvemin versus S0axisrawZ (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvemin_vs_S0axisrawZ_Background_Deco_Gauss;1	curvemin versus S0axisrawZ (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvemin_vs_S0axisrawZ_Background_Deco_Gauss;1	profile curvemin versus S0axisrawZ (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvemean_vs_S0axisrawZ_Signal_Deco_Gauss;1	curvemean versus S0axisrawZ (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvemean_vs_S0axisrawZ_Signal_Deco_Gauss;1	profile curvemean versus S0axisrawZ (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvemean_vs_S0axisrawZ_Background_Deco_Gauss;1	curvemean versus S0axisrawZ (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvemean_vs_S0axisrawZ_Background_Deco_Gauss;1	profile curvemean versus S0axisrawZ (Background)_Deco_Gauss
#      KEY: TH2F	scat_lambdamin_vs_S0axisrawZ_Signal_Deco_Gauss;1	lambdamin versus S0axisrawZ (Signal)_Deco_Gauss
#      KEY: TProfile	prof_lambdamin_vs_S0axisrawZ_Signal_Deco_Gauss;1	profile lambdamin versus S0axisrawZ (Signal)_Deco_Gauss
#      KEY: TH2F	scat_lambdamin_vs_S0axisrawZ_Background_Deco_Gauss;1	lambdamin versus S0axisrawZ (Background)_Deco_Gauss
#      KEY: TProfile	prof_lambdamin_vs_S0axisrawZ_Background_Deco_Gauss;1	profile lambdamin versus S0axisrawZ (Background)_Deco_Gauss
#      KEY: TH2F	scat_lambdamean_vs_S0axisrawZ_Signal_Deco_Gauss;1	lambdamean versus S0axisrawZ (Signal)_Deco_Gauss
#      KEY: TProfile	prof_lambdamean_vs_S0axisrawZ_Signal_Deco_Gauss;1	profile lambdamean versus S0axisrawZ (Signal)_Deco_Gauss
#      KEY: TH2F	scat_lambdamean_vs_S0axisrawZ_Background_Deco_Gauss;1	lambdamean versus S0axisrawZ (Background)_Deco_Gauss
#      KEY: TProfile	prof_lambdamean_vs_S0axisrawZ_Background_Deco_Gauss;1	profile lambdamean versus S0axisrawZ (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvesign_vs_S0axisrawZ_Signal_Deco_Gauss;1	curvesign versus S0axisrawZ (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvesign_vs_S0axisrawZ_Signal_Deco_Gauss;1	profile curvesign versus S0axisrawZ (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvesign_vs_S0axisrawZ_Background_Deco_Gauss;1	curvesign versus S0axisrawZ (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvesign_vs_S0axisrawZ_Background_Deco_Gauss;1	profile curvesign versus S0axisrawZ (Background)_Deco_Gauss
#      KEY: TH2F	scat_nCT_vs_phi_S0axisraw_Signal_Deco_Gauss;1	nCT versus phi_S0axisraw (Signal)_Deco_Gauss
#      KEY: TProfile	prof_nCT_vs_phi_S0axisraw_Signal_Deco_Gauss;1	profile nCT versus phi_S0axisraw (Signal)_Deco_Gauss
#      KEY: TH2F	scat_nCT_vs_phi_S0axisraw_Background_Deco_Gauss;1	nCT versus phi_S0axisraw (Background)_Deco_Gauss
#      KEY: TProfile	prof_nCT_vs_phi_S0axisraw_Background_Deco_Gauss;1	profile nCT versus phi_S0axisraw (Background)_Deco_Gauss
#      KEY: TH2F	scat_nGT_vs_phi_S0axisraw_Signal_Deco_Gauss;1	nGT versus phi_S0axisraw (Signal)_Deco_Gauss
#      KEY: TProfile	prof_nGT_vs_phi_S0axisraw_Signal_Deco_Gauss;1	profile nGT versus phi_S0axisraw (Signal)_Deco_Gauss
#      KEY: TH2F	scat_nGT_vs_phi_S0axisraw_Background_Deco_Gauss;1	nGT versus phi_S0axisraw (Background)_Deco_Gauss
#      KEY: TProfile	prof_nGT_vs_phi_S0axisraw_Background_Deco_Gauss;1	profile nGT versus phi_S0axisraw (Background)_Deco_Gauss
#      KEY: TH2F	scat_tracksdca_vs_phi_S0axisraw_Signal_Deco_Gauss;1	tracksdca versus phi_S0axisraw (Signal)_Deco_Gauss
#      KEY: TProfile	prof_tracksdca_vs_phi_S0axisraw_Signal_Deco_Gauss;1	profile tracksdca versus phi_S0axisraw (Signal)_Deco_Gauss
#      KEY: TH2F	scat_tracksdca_vs_phi_S0axisraw_Background_Deco_Gauss;1	tracksdca versus phi_S0axisraw (Background)_Deco_Gauss
#      KEY: TProfile	prof_tracksdca_vs_phi_S0axisraw_Background_Deco_Gauss;1	profile tracksdca versus phi_S0axisraw (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvemin_vs_phi_S0axisraw_Signal_Deco_Gauss;1	curvemin versus phi_S0axisraw (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvemin_vs_phi_S0axisraw_Signal_Deco_Gauss;1	profile curvemin versus phi_S0axisraw (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvemin_vs_phi_S0axisraw_Background_Deco_Gauss;1	curvemin versus phi_S0axisraw (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvemin_vs_phi_S0axisraw_Background_Deco_Gauss;1	profile curvemin versus phi_S0axisraw (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvemean_vs_phi_S0axisraw_Signal_Deco_Gauss;1	curvemean versus phi_S0axisraw (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvemean_vs_phi_S0axisraw_Signal_Deco_Gauss;1	profile curvemean versus phi_S0axisraw (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvemean_vs_phi_S0axisraw_Background_Deco_Gauss;1	curvemean versus phi_S0axisraw (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvemean_vs_phi_S0axisraw_Background_Deco_Gauss;1	profile curvemean versus phi_S0axisraw (Background)_Deco_Gauss
#      KEY: TH2F	scat_lambdamin_vs_phi_S0axisraw_Signal_Deco_Gauss;1	lambdamin versus phi_S0axisraw (Signal)_Deco_Gauss
#      KEY: TProfile	prof_lambdamin_vs_phi_S0axisraw_Signal_Deco_Gauss;1	profile lambdamin versus phi_S0axisraw (Signal)_Deco_Gauss
#      KEY: TH2F	scat_lambdamin_vs_phi_S0axisraw_Background_Deco_Gauss;1	lambdamin versus phi_S0axisraw (Background)_Deco_Gauss
#      KEY: TProfile	prof_lambdamin_vs_phi_S0axisraw_Background_Deco_Gauss;1	profile lambdamin versus phi_S0axisraw (Background)_Deco_Gauss
#      KEY: TH2F	scat_lambdamean_vs_phi_S0axisraw_Signal_Deco_Gauss;1	lambdamean versus phi_S0axisraw (Signal)_Deco_Gauss
#      KEY: TProfile	prof_lambdamean_vs_phi_S0axisraw_Signal_Deco_Gauss;1	profile lambdamean versus phi_S0axisraw (Signal)_Deco_Gauss
#      KEY: TH2F	scat_lambdamean_vs_phi_S0axisraw_Background_Deco_Gauss;1	lambdamean versus phi_S0axisraw (Background)_Deco_Gauss
#      KEY: TProfile	prof_lambdamean_vs_phi_S0axisraw_Background_Deco_Gauss;1	profile lambdamean versus phi_S0axisraw (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvesign_vs_phi_S0axisraw_Signal_Deco_Gauss;1	curvesign versus phi_S0axisraw (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvesign_vs_phi_S0axisraw_Signal_Deco_Gauss;1	profile curvesign versus phi_S0axisraw (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvesign_vs_phi_S0axisraw_Background_Deco_Gauss;1	curvesign versus phi_S0axisraw (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvesign_vs_phi_S0axisraw_Background_Deco_Gauss;1	profile curvesign versus phi_S0axisraw (Background)_Deco_Gauss
#      KEY: TH2F	scat_nGT_vs_nCT_Signal_Deco_Gauss;1	nGT versus nCT (Signal)_Deco_Gauss
#      KEY: TProfile	prof_nGT_vs_nCT_Signal_Deco_Gauss;1	profile nGT versus nCT (Signal)_Deco_Gauss
#      KEY: TH2F	scat_nGT_vs_nCT_Background_Deco_Gauss;1	nGT versus nCT (Background)_Deco_Gauss
#      KEY: TProfile	prof_nGT_vs_nCT_Background_Deco_Gauss;1	profile nGT versus nCT (Background)_Deco_Gauss
#      KEY: TH2F	scat_tracksdca_vs_nCT_Signal_Deco_Gauss;1	tracksdca versus nCT (Signal)_Deco_Gauss
#      KEY: TProfile	prof_tracksdca_vs_nCT_Signal_Deco_Gauss;1	profile tracksdca versus nCT (Signal)_Deco_Gauss
#      KEY: TH2F	scat_tracksdca_vs_nCT_Background_Deco_Gauss;1	tracksdca versus nCT (Background)_Deco_Gauss
#      KEY: TProfile	prof_tracksdca_vs_nCT_Background_Deco_Gauss;1	profile tracksdca versus nCT (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvemin_vs_nCT_Signal_Deco_Gauss;1	curvemin versus nCT (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvemin_vs_nCT_Signal_Deco_Gauss;1	profile curvemin versus nCT (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvemin_vs_nCT_Background_Deco_Gauss;1	curvemin versus nCT (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvemin_vs_nCT_Background_Deco_Gauss;1	profile curvemin versus nCT (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvemean_vs_nCT_Signal_Deco_Gauss;1	curvemean versus nCT (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvemean_vs_nCT_Signal_Deco_Gauss;1	profile curvemean versus nCT (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvemean_vs_nCT_Background_Deco_Gauss;1	curvemean versus nCT (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvemean_vs_nCT_Background_Deco_Gauss;1	profile curvemean versus nCT (Background)_Deco_Gauss
#      KEY: TH2F	scat_lambdamin_vs_nCT_Signal_Deco_Gauss;1	lambdamin versus nCT (Signal)_Deco_Gauss
#      KEY: TProfile	prof_lambdamin_vs_nCT_Signal_Deco_Gauss;1	profile lambdamin versus nCT (Signal)_Deco_Gauss
#      KEY: TH2F	scat_lambdamin_vs_nCT_Background_Deco_Gauss;1	lambdamin versus nCT (Background)_Deco_Gauss
#      KEY: TProfile	prof_lambdamin_vs_nCT_Background_Deco_Gauss;1	profile lambdamin versus nCT (Background)_Deco_Gauss
#      KEY: TH2F	scat_lambdamean_vs_nCT_Signal_Deco_Gauss;1	lambdamean versus nCT (Signal)_Deco_Gauss
#      KEY: TProfile	prof_lambdamean_vs_nCT_Signal_Deco_Gauss;1	profile lambdamean versus nCT (Signal)_Deco_Gauss
#      KEY: TH2F	scat_lambdamean_vs_nCT_Background_Deco_Gauss;1	lambdamean versus nCT (Background)_Deco_Gauss
#      KEY: TProfile	prof_lambdamean_vs_nCT_Background_Deco_Gauss;1	profile lambdamean versus nCT (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvesign_vs_nCT_Signal_Deco_Gauss;1	curvesign versus nCT (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvesign_vs_nCT_Signal_Deco_Gauss;1	profile curvesign versus nCT (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvesign_vs_nCT_Background_Deco_Gauss;1	curvesign versus nCT (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvesign_vs_nCT_Background_Deco_Gauss;1	profile curvesign versus nCT (Background)_Deco_Gauss
#      KEY: TH2F	scat_tracksdca_vs_nGT_Signal_Deco_Gauss;1	tracksdca versus nGT (Signal)_Deco_Gauss
#      KEY: TProfile	prof_tracksdca_vs_nGT_Signal_Deco_Gauss;1	profile tracksdca versus nGT (Signal)_Deco_Gauss
#      KEY: TH2F	scat_tracksdca_vs_nGT_Background_Deco_Gauss;1	tracksdca versus nGT (Background)_Deco_Gauss
#      KEY: TProfile	prof_tracksdca_vs_nGT_Background_Deco_Gauss;1	profile tracksdca versus nGT (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvemin_vs_nGT_Signal_Deco_Gauss;1	curvemin versus nGT (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvemin_vs_nGT_Signal_Deco_Gauss;1	profile curvemin versus nGT (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvemin_vs_nGT_Background_Deco_Gauss;1	curvemin versus nGT (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvemin_vs_nGT_Background_Deco_Gauss;1	profile curvemin versus nGT (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvemean_vs_nGT_Signal_Deco_Gauss;1	curvemean versus nGT (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvemean_vs_nGT_Signal_Deco_Gauss;1	profile curvemean versus nGT (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvemean_vs_nGT_Background_Deco_Gauss;1	curvemean versus nGT (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvemean_vs_nGT_Background_Deco_Gauss;1	profile curvemean versus nGT (Background)_Deco_Gauss
#      KEY: TH2F	scat_lambdamin_vs_nGT_Signal_Deco_Gauss;1	lambdamin versus nGT (Signal)_Deco_Gauss
#      KEY: TProfile	prof_lambdamin_vs_nGT_Signal_Deco_Gauss;1	profile lambdamin versus nGT (Signal)_Deco_Gauss
#      KEY: TH2F	scat_lambdamin_vs_nGT_Background_Deco_Gauss;1	lambdamin versus nGT (Background)_Deco_Gauss
#      KEY: TProfile	prof_lambdamin_vs_nGT_Background_Deco_Gauss;1	profile lambdamin versus nGT (Background)_Deco_Gauss
#      KEY: TH2F	scat_lambdamean_vs_nGT_Signal_Deco_Gauss;1	lambdamean versus nGT (Signal)_Deco_Gauss
#      KEY: TProfile	prof_lambdamean_vs_nGT_Signal_Deco_Gauss;1	profile lambdamean versus nGT (Signal)_Deco_Gauss
#      KEY: TH2F	scat_lambdamean_vs_nGT_Background_Deco_Gauss;1	lambdamean versus nGT (Background)_Deco_Gauss
#      KEY: TProfile	prof_lambdamean_vs_nGT_Background_Deco_Gauss;1	profile lambdamean versus nGT (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvesign_vs_nGT_Signal_Deco_Gauss;1	curvesign versus nGT (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvesign_vs_nGT_Signal_Deco_Gauss;1	profile curvesign versus nGT (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvesign_vs_nGT_Background_Deco_Gauss;1	curvesign versus nGT (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvesign_vs_nGT_Background_Deco_Gauss;1	profile curvesign versus nGT (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvemin_vs_tracksdca_Signal_Deco_Gauss;1	curvemin versus tracksdca (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvemin_vs_tracksdca_Signal_Deco_Gauss;1	profile curvemin versus tracksdca (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvemin_vs_tracksdca_Background_Deco_Gauss;1	curvemin versus tracksdca (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvemin_vs_tracksdca_Background_Deco_Gauss;1	profile curvemin versus tracksdca (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvemean_vs_tracksdca_Signal_Deco_Gauss;1	curvemean versus tracksdca (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvemean_vs_tracksdca_Signal_Deco_Gauss;1	profile curvemean versus tracksdca (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvemean_vs_tracksdca_Background_Deco_Gauss;1	curvemean versus tracksdca (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvemean_vs_tracksdca_Background_Deco_Gauss;1	profile curvemean versus tracksdca (Background)_Deco_Gauss
#      KEY: TH2F	scat_lambdamin_vs_tracksdca_Signal_Deco_Gauss;1	lambdamin versus tracksdca (Signal)_Deco_Gauss
#      KEY: TProfile	prof_lambdamin_vs_tracksdca_Signal_Deco_Gauss;1	profile lambdamin versus tracksdca (Signal)_Deco_Gauss
#      KEY: TH2F	scat_lambdamin_vs_tracksdca_Background_Deco_Gauss;1	lambdamin versus tracksdca (Background)_Deco_Gauss
#      KEY: TProfile	prof_lambdamin_vs_tracksdca_Background_Deco_Gauss;1	profile lambdamin versus tracksdca (Background)_Deco_Gauss
#      KEY: TH2F	scat_lambdamean_vs_tracksdca_Signal_Deco_Gauss;1	lambdamean versus tracksdca (Signal)_Deco_Gauss
#      KEY: TProfile	prof_lambdamean_vs_tracksdca_Signal_Deco_Gauss;1	profile lambdamean versus tracksdca (Signal)_Deco_Gauss
#      KEY: TH2F	scat_lambdamean_vs_tracksdca_Background_Deco_Gauss;1	lambdamean versus tracksdca (Background)_Deco_Gauss
#      KEY: TProfile	prof_lambdamean_vs_tracksdca_Background_Deco_Gauss;1	profile lambdamean versus tracksdca (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvesign_vs_tracksdca_Signal_Deco_Gauss;1	curvesign versus tracksdca (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvesign_vs_tracksdca_Signal_Deco_Gauss;1	profile curvesign versus tracksdca (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvesign_vs_tracksdca_Background_Deco_Gauss;1	curvesign versus tracksdca (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvesign_vs_tracksdca_Background_Deco_Gauss;1	profile curvesign versus tracksdca (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvemean_vs_curvemin_Signal_Deco_Gauss;1	curvemean versus curvemin (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvemean_vs_curvemin_Signal_Deco_Gauss;1	profile curvemean versus curvemin (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvemean_vs_curvemin_Background_Deco_Gauss;1	curvemean versus curvemin (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvemean_vs_curvemin_Background_Deco_Gauss;1	profile curvemean versus curvemin (Background)_Deco_Gauss
#      KEY: TH2F	scat_lambdamin_vs_curvemin_Signal_Deco_Gauss;1	lambdamin versus curvemin (Signal)_Deco_Gauss
#      KEY: TProfile	prof_lambdamin_vs_curvemin_Signal_Deco_Gauss;1	profile lambdamin versus curvemin (Signal)_Deco_Gauss
#      KEY: TH2F	scat_lambdamin_vs_curvemin_Background_Deco_Gauss;1	lambdamin versus curvemin (Background)_Deco_Gauss
#      KEY: TProfile	prof_lambdamin_vs_curvemin_Background_Deco_Gauss;1	profile lambdamin versus curvemin (Background)_Deco_Gauss
#      KEY: TH2F	scat_lambdamean_vs_curvemin_Signal_Deco_Gauss;1	lambdamean versus curvemin (Signal)_Deco_Gauss
#      KEY: TProfile	prof_lambdamean_vs_curvemin_Signal_Deco_Gauss;1	profile lambdamean versus curvemin (Signal)_Deco_Gauss
#      KEY: TH2F	scat_lambdamean_vs_curvemin_Background_Deco_Gauss;1	lambdamean versus curvemin (Background)_Deco_Gauss
#      KEY: TProfile	prof_lambdamean_vs_curvemin_Background_Deco_Gauss;1	profile lambdamean versus curvemin (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvesign_vs_curvemin_Signal_Deco_Gauss;1	curvesign versus curvemin (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvesign_vs_curvemin_Signal_Deco_Gauss;1	profile curvesign versus curvemin (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvesign_vs_curvemin_Background_Deco_Gauss;1	curvesign versus curvemin (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvesign_vs_curvemin_Background_Deco_Gauss;1	profile curvesign versus curvemin (Background)_Deco_Gauss
#      KEY: TH2F	scat_lambdamin_vs_curvemean_Signal_Deco_Gauss;1	lambdamin versus curvemean (Signal)_Deco_Gauss
#      KEY: TProfile	prof_lambdamin_vs_curvemean_Signal_Deco_Gauss;1	profile lambdamin versus curvemean (Signal)_Deco_Gauss
#      KEY: TH2F	scat_lambdamin_vs_curvemean_Background_Deco_Gauss;1	lambdamin versus curvemean (Background)_Deco_Gauss
#      KEY: TProfile	prof_lambdamin_vs_curvemean_Background_Deco_Gauss;1	profile lambdamin versus curvemean (Background)_Deco_Gauss
#      KEY: TH2F	scat_lambdamean_vs_curvemean_Signal_Deco_Gauss;1	lambdamean versus curvemean (Signal)_Deco_Gauss
#      KEY: TProfile	prof_lambdamean_vs_curvemean_Signal_Deco_Gauss;1	profile lambdamean versus curvemean (Signal)_Deco_Gauss
#      KEY: TH2F	scat_lambdamean_vs_curvemean_Background_Deco_Gauss;1	lambdamean versus curvemean (Background)_Deco_Gauss
#      KEY: TProfile	prof_lambdamean_vs_curvemean_Background_Deco_Gauss;1	profile lambdamean versus curvemean (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvesign_vs_curvemean_Signal_Deco_Gauss;1	curvesign versus curvemean (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvesign_vs_curvemean_Signal_Deco_Gauss;1	profile curvesign versus curvemean (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvesign_vs_curvemean_Background_Deco_Gauss;1	curvesign versus curvemean (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvesign_vs_curvemean_Background_Deco_Gauss;1	profile curvesign versus curvemean (Background)_Deco_Gauss
#      KEY: TH2F	scat_lambdamean_vs_lambdamin_Signal_Deco_Gauss;1	lambdamean versus lambdamin (Signal)_Deco_Gauss
#      KEY: TProfile	prof_lambdamean_vs_lambdamin_Signal_Deco_Gauss;1	profile lambdamean versus lambdamin (Signal)_Deco_Gauss
#      KEY: TH2F	scat_lambdamean_vs_lambdamin_Background_Deco_Gauss;1	lambdamean versus lambdamin (Background)_Deco_Gauss
#      KEY: TProfile	prof_lambdamean_vs_lambdamin_Background_Deco_Gauss;1	profile lambdamean versus lambdamin (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvesign_vs_lambdamin_Signal_Deco_Gauss;1	curvesign versus lambdamin (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvesign_vs_lambdamin_Signal_Deco_Gauss;1	profile curvesign versus lambdamin (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvesign_vs_lambdamin_Background_Deco_Gauss;1	curvesign versus lambdamin (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvesign_vs_lambdamin_Background_Deco_Gauss;1	profile curvesign versus lambdamin (Background)_Deco_Gauss
#      KEY: TH2F	scat_curvesign_vs_lambdamean_Signal_Deco_Gauss;1	curvesign versus lambdamean (Signal)_Deco_Gauss
#      KEY: TProfile	prof_curvesign_vs_lambdamean_Signal_Deco_Gauss;1	profile curvesign versus lambdamean (Signal)_Deco_Gauss
#      KEY: TH2F	scat_curvesign_vs_lambdamean_Background_Deco_Gauss;1	curvesign versus lambdamean (Background)_Deco_Gauss
#      KEY: TProfile	prof_curvesign_vs_lambdamean_Background_Deco_Gauss;1	profile curvesign versus lambdamean (Background)_Deco_Gauss
#     KEY: TH1F	nhits__Signal_Deco_Gauss;1	nhits
#     KEY: TH1F	nhits__Background_Deco_Gauss;1	nhits
#     KEY: TH1F	residual__Signal_Deco_Gauss;1	residual
#     KEY: TH1F	residual__Background_Deco_Gauss;1	residual
#     KEY: TH1F	r__Signal_Deco_Gauss;1	r
#     KEY: TH1F	r__Background_Deco_Gauss;1	r
#     KEY: TH1F	S0rawPerp__Signal_Deco_Gauss;1	S0rawPerp
#     KEY: TH1F	S0rawPerp__Background_Deco_Gauss;1	S0rawPerp
#     KEY: TH1F	S0axisrawZ__Signal_Deco_Gauss;1	S0axisrawZ
#     KEY: TH1F	S0axisrawZ__Background_Deco_Gauss;1	S0axisrawZ
#     KEY: TH1F	phi_S0axisraw__Signal_Deco_Gauss;1	phi_S0axisraw
#     KEY: TH1F	phi_S0axisraw__Background_Deco_Gauss;1	phi_S0axisraw
#     KEY: TH1F	nCT__Signal_Deco_Gauss;1	nCT
#     KEY: TH1F	nCT__Background_Deco_Gauss;1	nCT
#     KEY: TH1F	nGT__Signal_Deco_Gauss;1	nGT
#     KEY: TH1F	nGT__Background_Deco_Gauss;1	nGT
#     KEY: TH1F	tracksdca__Signal_Deco_Gauss;1	tracksdca
#     KEY: TH1F	tracksdca__Background_Deco_Gauss;1	tracksdca
#     KEY: TH1F	curvemin__Signal_Deco_Gauss;1	curvemin
#     KEY: TH1F	curvemin__Background_Deco_Gauss;1	curvemin
#     KEY: TH1F	curvemean__Signal_Deco_Gauss;1	curvemean
#     KEY: TH1F	curvemean__Background_Deco_Gauss;1	curvemean
#     KEY: TH1F	lambdamin__Signal_Deco_Gauss;1	lambdamin
#     KEY: TH1F	lambdamin__Background_Deco_Gauss;1	lambdamin
#     KEY: TH1F	lambdamean__Signal_Deco_Gauss;1	lambdamean
#     KEY: TH1F	lambdamean__Background_Deco_Gauss;1	lambdamean
#     KEY: TH1F	curvesign__Signal_Deco_Gauss;1	curvesign
#     KEY: TH1F	curvesign__Background_Deco_Gauss;1	curvesign
#     KEY: TDirectoryFile	CorrelationPlots;1	CorrelationPlots
#    TDirectoryFile*		Method_Fisher	Directory for all Fisher methods
#     TDirectoryFile*		Fisher	Fisher
#      TDirectoryFile*		CorrelationPlots	CorrelationPlots
#       KEY: TH2F	scat_residual_vs_nhits_Signal;1	residual versus nhits (Signal)
#       KEY: TProfile	prof_residual_vs_nhits_Signal;1	profile residual versus nhits (Signal)
#       KEY: TH2F	scat_residual_vs_nhits_Background;1	residual versus nhits (Background)
#       KEY: TProfile	prof_residual_vs_nhits_Background;1	profile residual versus nhits (Background)
#       KEY: TH2F	scat_r_vs_nhits_Signal;1	r versus nhits (Signal)
#       KEY: TProfile	prof_r_vs_nhits_Signal;1	profile r versus nhits (Signal)
#       KEY: TH2F	scat_r_vs_nhits_Background;1	r versus nhits (Background)
#       KEY: TProfile	prof_r_vs_nhits_Background;1	profile r versus nhits (Background)
#       KEY: TH2F	scat_S0rawPerp_vs_nhits_Signal;1	S0rawPerp versus nhits (Signal)
#       KEY: TProfile	prof_S0rawPerp_vs_nhits_Signal;1	profile S0rawPerp versus nhits (Signal)
#       KEY: TH2F	scat_S0rawPerp_vs_nhits_Background;1	S0rawPerp versus nhits (Background)
#       KEY: TProfile	prof_S0rawPerp_vs_nhits_Background;1	profile S0rawPerp versus nhits (Background)
#       KEY: TH2F	scat_S0axisrawZ_vs_nhits_Signal;1	S0axisrawZ versus nhits (Signal)
#       KEY: TProfile	prof_S0axisrawZ_vs_nhits_Signal;1	profile S0axisrawZ versus nhits (Signal)
#       KEY: TH2F	scat_S0axisrawZ_vs_nhits_Background;1	S0axisrawZ versus nhits (Background)
#       KEY: TProfile	prof_S0axisrawZ_vs_nhits_Background;1	profile S0axisrawZ versus nhits (Background)
#       KEY: TH2F	scat_phi_S0axisraw_vs_nhits_Signal;1	phi_S0axisraw versus nhits (Signal)
#       KEY: TProfile	prof_phi_S0axisraw_vs_nhits_Signal;1	profile phi_S0axisraw versus nhits (Signal)
#       KEY: TH2F	scat_phi_S0axisraw_vs_nhits_Background;1	phi_S0axisraw versus nhits (Background)
#       KEY: TProfile	prof_phi_S0axisraw_vs_nhits_Background;1	profile phi_S0axisraw versus nhits (Background)
#       KEY: TH2F	scat_nCT_vs_nhits_Signal;1	nCT versus nhits (Signal)
#       KEY: TProfile	prof_nCT_vs_nhits_Signal;1	profile nCT versus nhits (Signal)
#       KEY: TH2F	scat_nCT_vs_nhits_Background;1	nCT versus nhits (Background)
#       KEY: TProfile	prof_nCT_vs_nhits_Background;1	profile nCT versus nhits (Background)
#       KEY: TH2F	scat_nGT_vs_nhits_Signal;1	nGT versus nhits (Signal)
#       KEY: TProfile	prof_nGT_vs_nhits_Signal;1	profile nGT versus nhits (Signal)
#       KEY: TH2F	scat_nGT_vs_nhits_Background;1	nGT versus nhits (Background)
#       KEY: TProfile	prof_nGT_vs_nhits_Background;1	profile nGT versus nhits (Background)
#       KEY: TH2F	scat_tracksdca_vs_nhits_Signal;1	tracksdca versus nhits (Signal)
#       KEY: TProfile	prof_tracksdca_vs_nhits_Signal;1	profile tracksdca versus nhits (Signal)
#       KEY: TH2F	scat_tracksdca_vs_nhits_Background;1	tracksdca versus nhits (Background)
#       KEY: TProfile	prof_tracksdca_vs_nhits_Background;1	profile tracksdca versus nhits (Background)
#       KEY: TH2F	scat_curvemin_vs_nhits_Signal;1	curvemin versus nhits (Signal)
#       KEY: TProfile	prof_curvemin_vs_nhits_Signal;1	profile curvemin versus nhits (Signal)
#       KEY: TH2F	scat_curvemin_vs_nhits_Background;1	curvemin versus nhits (Background)
#       KEY: TProfile	prof_curvemin_vs_nhits_Background;1	profile curvemin versus nhits (Background)
#       KEY: TH2F	scat_curvemean_vs_nhits_Signal;1	curvemean versus nhits (Signal)
#       KEY: TProfile	prof_curvemean_vs_nhits_Signal;1	profile curvemean versus nhits (Signal)
#       KEY: TH2F	scat_curvemean_vs_nhits_Background;1	curvemean versus nhits (Background)
#       KEY: TProfile	prof_curvemean_vs_nhits_Background;1	profile curvemean versus nhits (Background)
#       KEY: TH2F	scat_lambdamin_vs_nhits_Signal;1	lambdamin versus nhits (Signal)
#       KEY: TProfile	prof_lambdamin_vs_nhits_Signal;1	profile lambdamin versus nhits (Signal)
#       KEY: TH2F	scat_lambdamin_vs_nhits_Background;1	lambdamin versus nhits (Background)
#       KEY: TProfile	prof_lambdamin_vs_nhits_Background;1	profile lambdamin versus nhits (Background)
#       KEY: TH2F	scat_lambdamean_vs_nhits_Signal;1	lambdamean versus nhits (Signal)
#       KEY: TProfile	prof_lambdamean_vs_nhits_Signal;1	profile lambdamean versus nhits (Signal)
#       KEY: TH2F	scat_lambdamean_vs_nhits_Background;1	lambdamean versus nhits (Background)
#       KEY: TProfile	prof_lambdamean_vs_nhits_Background;1	profile lambdamean versus nhits (Background)
#       KEY: TH2F	scat_curvesign_vs_nhits_Signal;1	curvesign versus nhits (Signal)
#       KEY: TProfile	prof_curvesign_vs_nhits_Signal;1	profile curvesign versus nhits (Signal)
# ...
#       KEY: TProfile	prof_curvemin_vs_phi_S0axisraw_Signal;1	profile curvemin versus phi_S0axisraw (Signal)
#       KEY: TH2F	scat_curvemin_vs_phi_S0axisraw_Background;1	curvemin versus phi_S0axisraw (Background)
#       KEY: TProfile	prof_curvemin_vs_phi_S0axisraw_Background;1	profile curvemin versus phi_S0axisraw (Background)
#       KEY: TH2F	scat_curvemean_vs_phi_S0axisraw_Signal;1	curvemean versus phi_S0axisraw (Signal)
#       KEY: TProfile	prof_curvemean_vs_phi_S0axisraw_Signal;1	profile curvemean versus phi_S0axisraw (Signal)
#       KEY: TH2F	scat_curvemean_vs_phi_S0axisraw_Background;1	curvemean versus phi_S0axisraw (Background)
#       KEY: TProfile	prof_curvemean_vs_phi_S0axisraw_Background;1	profile curvemean versus phi_S0axisraw (Background)
#       KEY: TH2F	scat_lambdamin_vs_phi_S0axisraw_Signal;1	lambdamin versus phi_S0axisraw (Signal)
#       KEY: TProfile	prof_lambdamin_vs_phi_S0axisraw_Signal;1	profile lambdamin versus phi_S0axisraw (Signal)
#       KEY: TH2F	scat_lambdamin_vs_phi_S0axisraw_Background;1	lambdamin versus phi_S0axisraw (Background)
#       KEY: TProfile	prof_lambdamin_vs_phi_S0axisraw_Background;1	profile lambdamin versus phi_S0axisraw (Background)
#       KEY: TH2F	scat_lambdamean_vs_phi_S0axisraw_Signal;1	lambdamean versus phi_S0axisraw (Signal)
#       KEY: TProfile	prof_lambdamean_vs_phi_S0axisraw_Signal;1	profile lambdamean versus phi_S0axisraw (Signal)
#       KEY: TH2F	scat_lambdamean_vs_phi_S0axisraw_Background;1	lambdamean versus phi_S0axisraw (Background)
#       KEY: TProfile	prof_lambdamean_vs_phi_S0axisraw_Background;1	profile lambdamean versus phi_S0axisraw (Background)
#       KEY: TH2F	scat_curvesign_vs_phi_S0axisraw_Signal;1	curvesign versus phi_S0axisraw (Signal)
#       KEY: TProfile	prof_curvesign_vs_phi_S0axisraw_Signal;1	profile curvesign versus phi_S0axisraw (Signal)
#       KEY: TH2F	scat_curvesign_vs_phi_S0axisraw_Background;1	curvesign versus phi_S0axisraw (Background)
#       KEY: TProfile	prof_curvesign_vs_phi_S0axisraw_Background;1	profile curvesign versus phi_S0axisraw (Background)
#       KEY: TH2F	scat_nGT_vs_nCT_Signal;1	nGT versus nCT (Signal)
#       KEY: TProfile	prof_nGT_vs_nCT_Signal;1	profile nGT versus nCT (Signal)
#       KEY: TH2F	scat_nGT_vs_nCT_Background;1	nGT versus nCT (Background)
#       KEY: TProfile	prof_nGT_vs_nCT_Background;1	profile nGT versus nCT (Background)
#       KEY: TH2F	scat_tracksdca_vs_nCT_Signal;1	tracksdca versus nCT (Signal)
#       KEY: TProfile	prof_tracksdca_vs_nCT_Signal;1	profile tracksdca versus nCT (Signal)
#       KEY: TH2F	scat_tracksdca_vs_nCT_Background;1	tracksdca versus nCT (Background)
#       KEY: TProfile	prof_tracksdca_vs_nCT_Background;1	profile tracksdca versus nCT (Background)
#       KEY: TH2F	scat_curvemin_vs_nCT_Signal;1	curvemin versus nCT (Signal)
#       KEY: TProfile	prof_curvemin_vs_nCT_Signal;1	profile curvemin versus nCT (Signal)
#       KEY: TH2F	scat_curvemin_vs_nCT_Background;1	curvemin versus nCT (Background)
#       KEY: TProfile	prof_curvemin_vs_nCT_Background;1	profile curvemin versus nCT (Background)
#       KEY: TH2F	scat_curvemean_vs_nCT_Signal;1	curvemean versus nCT (Signal)
#       KEY: TProfile	prof_curvemean_vs_nCT_Signal;1	profile curvemean versus nCT (Signal)
#       KEY: TH2F	scat_curvemean_vs_nCT_Background;1	curvemean versus nCT (Background)
#       KEY: TProfile	prof_curvemean_vs_nCT_Background;1	profile curvemean versus nCT (Background)
#       KEY: TH2F	scat_lambdamin_vs_nCT_Signal;1	lambdamin versus nCT (Signal)
#       KEY: TProfile	prof_lambdamin_vs_nCT_Signal;1	profile lambdamin versus nCT (Signal)
#       KEY: TH2F	scat_lambdamin_vs_nCT_Background;1	lambdamin versus nCT (Background)
#       KEY: TProfile	prof_lambdamin_vs_nCT_Background;1	profile lambdamin versus nCT (Background)
#       KEY: TH2F	scat_lambdamean_vs_nCT_Signal;1	lambdamean versus nCT (Signal)
#       KEY: TProfile	prof_lambdamean_vs_nCT_Signal;1	profile lambdamean versus nCT (Signal)
#       KEY: TH2F	scat_lambdamean_vs_nCT_Background;1	lambdamean versus nCT (Background)
#       KEY: TProfile	prof_lambdamean_vs_nCT_Background;1	profile lambdamean versus nCT (Background)
#       KEY: TH2F	scat_curvesign_vs_nCT_Signal;1	curvesign versus nCT (Signal)
#       KEY: TProfile	prof_curvesign_vs_nCT_Signal;1	profile curvesign versus nCT (Signal)
#       KEY: TH2F	scat_curvesign_vs_nCT_Background;1	curvesign versus nCT (Background)
#       KEY: TProfile	prof_curvesign_vs_nCT_Background;1	profile curvesign versus nCT (Background)
#       KEY: TH2F	scat_tracksdca_vs_nGT_Signal;1	tracksdca versus nGT (Signal)
#       KEY: TProfile	prof_tracksdca_vs_nGT_Signal;1	profile tracksdca versus nGT (Signal)
#       KEY: TH2F	scat_tracksdca_vs_nGT_Background;1	tracksdca versus nGT (Background)
#       KEY: TProfile	prof_tracksdca_vs_nGT_Background;1	profile tracksdca versus nGT (Background)
#       KEY: TH2F	scat_curvemin_vs_nGT_Signal;1	curvemin versus nGT (Signal)
#       KEY: TProfile	prof_curvemin_vs_nGT_Signal;1	profile curvemin versus nGT (Signal)
#       KEY: TH2F	scat_curvemin_vs_nGT_Background;1	curvemin versus nGT (Background)
#       KEY: TProfile	prof_curvemin_vs_nGT_Background;1	profile curvemin versus nGT (Background)
#       KEY: TH2F	scat_curvemean_vs_nGT_Signal;1	curvemean versus nGT (Signal)
#       KEY: TProfile	prof_curvemean_vs_nGT_Signal;1	profile curvemean versus nGT (Signal)
#       KEY: TH2F	scat_curvemean_vs_nGT_Background;1	curvemean versus nGT (Background)
#       KEY: TProfile	prof_curvemean_vs_nGT_Background;1	profile curvemean versus nGT (Background)
#       KEY: TH2F	scat_lambdamin_vs_nGT_Signal;1	lambdamin versus nGT (Signal)
#       KEY: TProfile	prof_lambdamin_vs_nGT_Signal;1	profile lambdamin versus nGT (Signal)
#       KEY: TH2F	scat_lambdamin_vs_nGT_Background;1	lambdamin versus nGT (Background)
#       KEY: TProfile	prof_lambdamin_vs_nGT_Background;1	profile lambdamin versus nGT (Background)
#       KEY: TH2F	scat_lambdamean_vs_nGT_Signal;1	lambdamean versus nGT (Signal)
#       KEY: TProfile	prof_lambdamean_vs_nGT_Signal;1	profile lambdamean versus nGT (Signal)
#       KEY: TH2F	scat_lambdamean_vs_nGT_Background;1	lambdamean versus nGT (Background)
#       KEY: TProfile	prof_lambdamean_vs_nGT_Background;1	profile lambdamean versus nGT (Background)
#       KEY: TH2F	scat_curvesign_vs_nGT_Signal;1	curvesign versus nGT (Signal)
#       KEY: TProfile	prof_curvesign_vs_nGT_Signal;1	profile curvesign versus nGT (Signal)
#       KEY: TH2F	scat_curvesign_vs_nGT_Background;1	curvesign versus nGT (Background)
#       KEY: TProfile	prof_curvesign_vs_nGT_Background;1	profile curvesign versus nGT (Background)
#       KEY: TH2F	scat_curvemin_vs_tracksdca_Signal;1	curvemin versus tracksdca (Signal)
#       KEY: TProfile	prof_curvemin_vs_tracksdca_Signal;1	profile curvemin versus tracksdca (Signal)
#       KEY: TH2F	scat_curvemin_vs_tracksdca_Background;1	curvemin versus tracksdca (Background)
#       KEY: TProfile	prof_curvemin_vs_tracksdca_Background;1	profile curvemin versus tracksdca (Background)
#       KEY: TH2F	scat_curvemean_vs_tracksdca_Signal;1	curvemean versus tracksdca (Signal)
#       KEY: TProfile	prof_curvemean_vs_tracksdca_Signal;1	profile curvemean versus tracksdca (Signal)
#       KEY: TH2F	scat_curvemean_vs_tracksdca_Background;1	curvemean versus tracksdca (Background)
#       KEY: TProfile	prof_curvemean_vs_tracksdca_Background;1	profile curvemean versus tracksdca (Background)
#       KEY: TH2F	scat_lambdamin_vs_tracksdca_Signal;1	lambdamin versus tracksdca (Signal)
#       KEY: TProfile	prof_lambdamin_vs_tracksdca_Signal;1	profile lambdamin versus tracksdca (Signal)
#       KEY: TH2F	scat_lambdamin_vs_tracksdca_Background;1	lambdamin versus tracksdca (Background)
#       KEY: TProfile	prof_lambdamin_vs_tracksdca_Background;1	profile lambdamin versus tracksdca (Background)
#       KEY: TH2F	scat_lambdamean_vs_tracksdca_Signal;1	lambdamean versus tracksdca (Signal)
#       KEY: TProfile	prof_lambdamean_vs_tracksdca_Signal;1	profile lambdamean versus tracksdca (Signal)
#       KEY: TH2F	scat_lambdamean_vs_tracksdca_Background;1	lambdamean versus tracksdca (Background)
#       KEY: TProfile	prof_lambdamean_vs_tracksdca_Background;1	profile lambdamean versus tracksdca (Background)
#       KEY: TH2F	scat_curvesign_vs_tracksdca_Signal;1	curvesign versus tracksdca (Signal)
#       KEY: TProfile	prof_curvesign_vs_tracksdca_Signal;1	profile curvesign versus tracksdca (Signal)
#       KEY: TH2F	scat_curvesign_vs_tracksdca_Background;1	curvesign versus tracksdca (Background)
#       KEY: TProfile	prof_curvesign_vs_tracksdca_Background;1	profile curvesign versus tracksdca (Background)
#       KEY: TH2F	scat_curvemean_vs_curvemin_Signal;1	curvemean versus curvemin (Signal)
#       KEY: TProfile	prof_curvemean_vs_curvemin_Signal;1	profile curvemean versus curvemin (Signal)
#       KEY: TH2F	scat_curvemean_vs_curvemin_Background;1	curvemean versus curvemin (Background)
#       KEY: TProfile	prof_curvemean_vs_curvemin_Background;1	profile curvemean versus curvemin (Background)
#       KEY: TH2F	scat_lambdamin_vs_curvemin_Signal;1	lambdamin versus curvemin (Signal)
#       KEY: TProfile	prof_lambdamin_vs_curvemin_Signal;1	profile lambdamin versus curvemin (Signal)
#       KEY: TH2F	scat_lambdamin_vs_curvemin_Background;1	lambdamin versus curvemin (Background)
#       KEY: TProfile	prof_lambdamin_vs_curvemin_Background;1	profile lambdamin versus curvemin (Background)
#       KEY: TH2F	scat_lambdamean_vs_curvemin_Signal;1	lambdamean versus curvemin (Signal)
#       KEY: TProfile	prof_lambdamean_vs_curvemin_Signal;1	profile lambdamean versus curvemin (Signal)
#       KEY: TH2F	scat_lambdamean_vs_curvemin_Background;1	lambdamean versus curvemin (Background)
#       KEY: TProfile	prof_lambdamean_vs_curvemin_Background;1	profile lambdamean versus curvemin (Background)
#       KEY: TH2F	scat_curvesign_vs_curvemin_Signal;1	curvesign versus curvemin (Signal)
#       KEY: TProfile	prof_curvesign_vs_curvemin_Signal;1	profile curvesign versus curvemin (Signal)
#       KEY: TH2F	scat_curvesign_vs_curvemin_Background;1	curvesign versus curvemin (Background)
#       KEY: TProfile	prof_curvesign_vs_curvemin_Background;1	profile curvesign versus curvemin (Background)
#       KEY: TH2F	scat_lambdamin_vs_curvemean_Signal;1	lambdamin versus curvemean (Signal)
#       KEY: TProfile	prof_lambdamin_vs_curvemean_Signal;1	profile lambdamin versus curvemean (Signal)
#       KEY: TH2F	scat_lambdamin_vs_curvemean_Background;1	lambdamin versus curvemean (Background)
#       KEY: TProfile	prof_lambdamin_vs_curvemean_Background;1	profile lambdamin versus curvemean (Background)
#       KEY: TH2F	scat_lambdamean_vs_curvemean_Signal;1	lambdamean versus curvemean (Signal)
#       KEY: TProfile	prof_lambdamean_vs_curvemean_Signal;1	profile lambdamean versus curvemean (Signal)
#       KEY: TH2F	scat_lambdamean_vs_curvemean_Background;1	lambdamean versus curvemean (Background)
#       KEY: TProfile	prof_lambdamean_vs_curvemean_Background;1	profile lambdamean versus curvemean (Background)
#       KEY: TH2F	scat_curvesign_vs_curvemean_Signal;1	curvesign versus curvemean (Signal)
#       KEY: TProfile	prof_curvesign_vs_curvemean_Signal;1	profile curvesign versus curvemean (Signal)
#       KEY: TH2F	scat_curvesign_vs_curvemean_Background;1	curvesign versus curvemean (Background)
#       KEY: TProfile	prof_curvesign_vs_curvemean_Background;1	profile curvesign versus curvemean (Background)
#       KEY: TH2F	scat_lambdamean_vs_lambdamin_Signal;1	lambdamean versus lambdamin (Signal)
#       KEY: TProfile	prof_lambdamean_vs_lambdamin_Signal;1	profile lambdamean versus lambdamin (Signal)
#       KEY: TH2F	scat_lambdamean_vs_lambdamin_Background;1	lambdamean versus lambdamin (Background)
#       KEY: TProfile	prof_lambdamean_vs_lambdamin_Background;1	profile lambdamean versus lambdamin (Background)
#       KEY: TH2F	scat_curvesign_vs_lambdamin_Signal;1	curvesign versus lambdamin (Signal)
#       KEY: TProfile	prof_curvesign_vs_lambdamin_Signal;1	profile curvesign versus lambdamin (Signal)
#       KEY: TH2F	scat_curvesign_vs_lambdamin_Background;1	curvesign versus lambdamin (Background)
#       KEY: TProfile	prof_curvesign_vs_lambdamin_Background;1	profile curvesign versus lambdamin (Background)
#       KEY: TH2F	scat_curvesign_vs_lambdamean_Signal;1	curvesign versus lambdamean (Signal)
#       KEY: TProfile	prof_curvesign_vs_lambdamean_Signal;1	profile curvesign versus lambdamean (Signal)
#       KEY: TH2F	scat_curvesign_vs_lambdamean_Background;1	curvesign versus lambdamean (Background)
#       KEY: TProfile	prof_curvesign_vs_lambdamean_Background;1	profile curvesign versus lambdamean (Background)
#      KEY: TObjString	TrainingPath;1	Collectable string class
#      KEY: TObjString	WeightFileName;1	Collectable string class
#      KEY: TTree	MonitorNtuple;1	BDT variables
#      KEY: TH1D	MVA_BDTG_S;1	MVA_BDTG_S
#      KEY: TH1D	MVA_BDTG_B;1	MVA_BDTG_B
#      KEY: TH1D	MVA_BDTG_S_high;1	MVA_BDTG_S_high
#      KEY: TH1D	MVA_BDTG_B_high;1	MVA_BDTG_B_high
#      KEY: TH1D	MVA_BDTG_effS;1	MVA_BDTG (signal)
#      KEY: TH1D	MVA_BDTG_effB;1	MVA_BDTG (background)
#      KEY: TH1D	MVA_BDTG_effBvsS;1	MVA_BDTG
#      KEY: TH1D	MVA_BDTG_rejBvsS;1	MVA_BDTG
#      KEY: TH1D	MVA_BDTG_invBeffvsSeff;1	MVA_BDTG
#      KEY: TH1D	MVA_BDTG_Train_S;1	MVA_BDTG_Train_S
#      KEY: TH1D	MVA_BDTG_Train_B;1	MVA_BDTG_Train_B
#      KEY: TH1D	MVA_BDTG_trainingEffS;1	MVA_BDTG (signal)
#      KEY: TH1D	MVA_BDTG_trainingEffB;1	MVA_BDTG (background)
#      KEY: TH1D	MVA_BDTG_trainingEffBvsS;1	MVA_BDTG
#      KEY: TH1D	MVA_BDTG_trainingRejBvsS;1	MVA_BDTG
#      KEY: TH1F	nhits__Signal;1	nhits
#      KEY: TH1F	nhits__Background;1	nhits
#      KEY: TH1F	residual__Signal;1	residual
#      KEY: TH1F	residual__Background;1	residual
#      KEY: TH1F	r__Signal;1	r
#      KEY: TH1F	r__Background;1	r
#      KEY: TH1F	S0rawPerp__Signal;1	S0rawPerp
#      KEY: TH1F	S0rawPerp__Background;1	S0rawPerp
#      KEY: TH1F	S0axisrawZ__Signal;1	S0axisrawZ
#      KEY: TH1F	S0axisrawZ__Background;1	S0axisrawZ
#      KEY: TH1F	phi_S0axisraw__Signal;1	phi_S0axisraw
#      KEY: TH1F	phi_S0axisraw__Background;1	phi_S0axisraw
#      KEY: TH1F	nCT__Signal;1	nCT
#      KEY: TH1F	nCT__Background;1	nCT
#      KEY: TH1F	nGT__Signal;1	nGT
#      KEY: TH1F	nGT__Background;1	nGT
#      KEY: TH1F	tracksdca__Signal;1	tracksdca
#      KEY: TH1F	tracksdca__Background;1	tracksdca
#      KEY: TH1F	curvemin__Signal;1	curvemin
#      KEY: TH1F	curvemin__Background;1	curvemin
#      KEY: TH1F	curvemean__Signal;1	curvemean
#      KEY: TH1F	curvemean__Background;1	curvemean
#      KEY: TH1F	lambdamin__Signal;1	lambdamin
#      KEY: TH1F	lambdamin__Background;1	lambdamin
#      KEY: TH1F	lambdamean__Signal;1	lambdamean
#      KEY: TH1F	lambdamean__Background;1	lambdamean
#      KEY: TH1F	curvesign__Signal;1	curvesign
#      KEY: TH1F	curvesign__Background;1	curvesign
#      KEY: TDirectoryFile	CorrelationPlots;1	CorrelationPlots
#      KEY: TH1F	dataset_BoostWeight;1	AdaBooost weight distribution
#      KEY: TH1F	BoostWeightVsTree;1	Boost weights vs tree
#      KEY: TH1F	ErrFractHist;1	error fraction vs tree number
#      KEY: TH1I	dataset_NodesBeforePruning;1	nodes before pruning
#      KEY: TH1I	dataset_NodesAfterPruning;1	nodes after pruning
#     KEY: TDirectoryFile	BDT;1	BDT
#     KEY: TDirectoryFile	BDTB;1	BDTB
#     KEY: TDirectoryFile	BDTG;1	BDTG
#    OBJ: TTree	TestTree	TestTree : 0 at: 0x10ec34b0
#    OBJ: TTree	TrainTree	TrainTree : 0 at: 0x119f9a80
#    KEY: TH2F	CorrelationMatrixS;1	Correlation Matrix (signal)
#    KEY: TH2F	CorrelationMatrixB;1	Correlation Matrix (background)
#    KEY: TDirectoryFile	InputVariables_Deco_Gauss;1	InputVariables_Deco_Gauss
#    KEY: TDirectoryFile	Method_Fisher;1	Directory for all Fisher methods
#    KEY: TDirectoryFile	Method_PyKeras;1	Directory for all PyKeras methods
#    KEY: TDirectoryFile	Method_Cuts;1	Directory for all Cuts methods
#    KEY: TDirectoryFile	Method_KNN;1	Directory for all KNN methods
#    KEY: TDirectoryFile	Method_SVM;1	Directory for all SVM methods
#    KEY: TDirectoryFile	Method_BDT;1	Directory for all BDT methods
#    KEY: TTree	TestTree;1	TestTree
#    KEY: TTree	TrainTree;1	TrainTree
#   KEY: TDirectoryFile	dataset;1	dataset

# %%
output.Close()

# %% [markdown]
# # Test on a real experiment (not labeled training data)

# %%
from array import array
from ROOT import TString
experiment_data = TFile.Open('sample_experiment.root')
testsignal = experiment_data.Get('sample_experiment')


reader = TMVA.Reader( "!Color:!Silent" );
#for variable in variable_list:
#    reader.AddVariable(variable)

    
    
branches = {}
for branch in testsignal.GetListOfBranches():
    branchName = branch.GetName()
    branches[branchName] = array('f', [-999])
    reader.AddVariable(branchName, branches[branchName])
    testsignal.SetBranchAddress(branchName, branches[branchName])
 
# Book methods
#reader.BookMVA('PyKeras', TString('dataset/weights/TMVAClassification_PyKeras.weights.xml'))
for method in active_mva_list:
    reader.BookMVA(TString(method), TString('dataset/weights/TMVAClassification_' + method + '.weights.xml'))

# Print some example classifications
print('Some signal example classifications:')
threshold = 0.5
efficiency = 0.5



for method in active_mva_list:
    print(method)
    counts = 0
    mean_model_output = 0.0
    for i in range(testsignal.GetEntries()):
        testsignal.GetEntry(i)
        mean_model_output += reader.EvaluateMVA(TString(method))
        if reader.EvaluateMVA(TString(method)) > threshold:
            counts += 1
        #print(reader.EvaluateMVA(TString(method)))
    print('Mean model output ' + str ( mean_model_output / testsignal.GetEntries() ))
    print( '\tTotal Signal = ' + str(counts) + '/' + str(testsignal.GetEntries()))
    print( '\tEstimated Population = ' + str(counts/efficiency) + '(' + str(testsignal.GetEntries() - 10) + ')')
print('')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_13046/4238086059.py in <module>
#      21 #reader.BookMVA('PyKeras', TString('dataset/weights/TMVAClassification_PyKeras.weights.xml'))
#      22 for method in active_mva_list:
# ---> 23     reader.BookMVA(TString(method), TString('dataset/weights/TMVAClassification_' + method + '.weights.xml'))
#      24
#      25 # Print some example classifications
#
# TypeError: none of the 2 overloaded methods succeeded. Full details:
#   TMVA::IMethod* TMVA::Reader::BookMVA(const TString& methodTag, const TString& weightfile) =>
#     runtime_error: FATAL error
#   TMVA::IMethod* TMVA::Reader::BookMVA(TMVA::Types::EMVA methodType, const char* xmlstr) =>
#     TypeError: could not convert argument 1 (an integer is required)
#                          : Booking "Fisher" of type "Fisher" from dataset/weights/TMVAClassification_Fisher.weights.xml.
#                          : Reading weight file: dataset/weights/TMVAClassification_Fisher.weights.xml
# <FATAL>                          : Dataset[Default] : You declared 18 variables in the Reader while there are 14 variables declared in the file
# ***> abort program execution
